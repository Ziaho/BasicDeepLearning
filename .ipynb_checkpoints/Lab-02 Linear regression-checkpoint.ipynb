# %%
import torch

# %%
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[2], [4], [6]])

# %%
W = torch.zeros(1, requires_grad=True)
b = torch.zeros(1, requires_grad=True)

optimizer = torch.optim.SGD([W, b], lr = 0.01)
hypothesis = W * x_train + b

# %%
for i in range(0, 1000):
    hypothesis = W * x_train + b
    cost = torch.mean((hypothesis - y_train) ** 2)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    print(W, b)
# Out:
# tensor([0.1867], requires_grad=True) tensor([0.0800], requires_grad=True)
# tensor([0.3527], requires_grad=True) tensor([0.1509], requires_grad=True)
# tensor([0.5004], requires_grad=True) tensor([0.2138], requires_grad=True)
# tensor([0.6318], requires_grad=True) tensor([0.2695], requires_grad=True)
# tensor([0.7487], requires_grad=True) tensor([0.3188], requires_grad=True)
# tensor([0.8528], requires_grad=True) tensor([0.3625], requires_grad=True)
# tensor([0.9453], requires_grad=True) tensor([0.4012], requires_grad=True)
# tensor([1.0277], requires_grad=True) tensor([0.4353], requires_grad=True)
# tensor([1.1011], requires_grad=True) tensor([0.4655], requires_grad=True)
# tensor([1.1663], requires_grad=True) tensor([0.4922], requires_grad=True)
# tensor([1.2245], requires_grad=True) tensor([0.5157], requires_grad=True)
# tensor([1.2762], requires_grad=True) tensor([0.5364], requires_grad=True)
# tensor([1.3223], requires_grad=True) tensor([0.5546], requires_grad=True)
# tensor([1.3634], requires_grad=True) tensor([0.5706], requires_grad=True)
# tensor([1.4000], requires_grad=True) tensor([0.5847], requires_grad=True)
# tensor([1.4326], requires_grad=True) tensor([0.5970], requires_grad=True)
# tensor([1.4617], requires_grad=True) tensor([0.6077], requires_grad=True)
# tensor([1.4876], requires_grad=True) tensor([0.6171], requires_grad=True)
# tensor([1.5107], requires_grad=True) tensor([0.6253], requires_grad=True)
# tensor([1.5314], requires_grad=True) tensor([0.6323], requires_grad=True)
# tensor([1.5498], requires_grad=True) tensor([0.6384], requires_grad=True)
# tensor([1.5663], requires_grad=True) tensor([0.6437], requires_grad=True)
# tensor([1.5811], requires_grad=True) tensor([0.6481], requires_grad=True)
# tensor([1.5942], requires_grad=True) tensor([0.6519], requires_grad=True)
# tensor([1.6060], requires_grad=True) tensor([0.6551], requires_grad=True)
# tensor([1.6166], requires_grad=True) tensor([0.6578], requires_grad=True)
# tensor([1.6261], requires_grad=True) tensor([0.6600], requires_grad=True)
# tensor([1.6346], requires_grad=True) tensor([0.6617], requires_grad=True)
# tensor([1.6422], requires_grad=True) tensor([0.6631], requires_grad=True)
# tensor([1.6491], requires_grad=True) tensor([0.6641], requires_grad=True)
# tensor([1.6553], requires_grad=True) tensor([0.6649], requires_grad=True)
# tensor([1.6608], requires_grad=True) tensor([0.6654], requires_grad=True)
# tensor([1.6659], requires_grad=True) tensor([0.6656], requires_grad=True)
# tensor([1.6704], requires_grad=True) tensor([0.6657], requires_grad=True)
# tensor([1.6746], requires_grad=True) tensor([0.6656], requires_grad=True)
# tensor([1.6783], requires_grad=True) tensor([0.6653], requires_grad=True)
# tensor([1.6817], requires_grad=True) tensor([0.6648], requires_grad=True)
# tensor([1.6848], requires_grad=True) tensor([0.6643], requires_grad=True)
# tensor([1.6877], requires_grad=True) tensor([0.6636], requires_grad=True)
# tensor([1.6903], requires_grad=True) tensor([0.6628], requires_grad=True)
# tensor([1.6927], requires_grad=True) tensor([0.6619], requires_grad=True)
# tensor([1.6949], requires_grad=True) tensor([0.6610], requires_grad=True)
# tensor([1.6969], requires_grad=True) tensor([0.6600], requires_grad=True)
# tensor([1.6988], requires_grad=True) tensor([0.6589], requires_grad=True)
# tensor([1.7006], requires_grad=True) tensor([0.6578], requires_grad=True)
# tensor([1.7022], requires_grad=True) tensor([0.6566], requires_grad=True)
# tensor([1.7037], requires_grad=True) tensor([0.6554], requires_grad=True)
# tensor([1.7052], requires_grad=True) tensor([0.6541], requires_grad=True)
# tensor([1.7065], requires_grad=True) tensor([0.6528], requires_grad=True)
# tensor([1.7078], requires_grad=True) tensor([0.6515], requires_grad=True)
# tensor([1.7090], requires_grad=True) tensor([0.6502], requires_grad=True)
# tensor([1.7102], requires_grad=True) tensor([0.6488], requires_grad=True)
# tensor([1.7113], requires_grad=True) tensor([0.6474], requires_grad=True)
# tensor([1.7123], requires_grad=True) tensor([0.6460], requires_grad=True)
# tensor([1.7133], requires_grad=True) tensor([0.6446], requires_grad=True)
# tensor([1.7143], requires_grad=True) tensor([0.6432], requires_grad=True)
# tensor([1.7152], requires_grad=True) tensor([0.6417], requires_grad=True)
# tensor([1.7161], requires_grad=True) tensor([0.6403], requires_grad=True)
# tensor([1.7170], requires_grad=True) tensor([0.6389], requires_grad=True)
# tensor([1.7179], requires_grad=True) tensor([0.6374], requires_grad=True)
# tensor([1.7187], requires_grad=True) tensor([0.6359], requires_grad=True)
# tensor([1.7195], requires_grad=True) tensor([0.6345], requires_grad=True)
# tensor([1.7203], requires_grad=True) tensor([0.6330], requires_grad=True)
# tensor([1.7211], requires_grad=True) tensor([0.6315], requires_grad=True)
# tensor([1.7219], requires_grad=True) tensor([0.6300], requires_grad=True)
# tensor([1.7226], requires_grad=True) tensor([0.6286], requires_grad=True)
# tensor([1.7234], requires_grad=True) tensor([0.6271], requires_grad=True)
# tensor([1.7241], requires_grad=True) tensor([0.6256], requires_grad=True)
# tensor([1.7248], requires_grad=True) tensor([0.6241], requires_grad=True)
# tensor([1.7256], requires_grad=True) tensor([0.6227], requires_grad=True)
# tensor([1.7263], requires_grad=True) tensor([0.6212], requires_grad=True)
# tensor([1.7270], requires_grad=True) tensor([0.6197], requires_grad=True)
# tensor([1.7277], requires_grad=True) tensor([0.6182], requires_grad=True)
# tensor([1.7283], requires_grad=True) tensor([0.6168], requires_grad=True)
# tensor([1.7290], requires_grad=True) tensor([0.6153], requires_grad=True)
# tensor([1.7297], requires_grad=True) tensor([0.6138], requires_grad=True)
# tensor([1.7304], requires_grad=True) tensor([0.6124], requires_grad=True)
# tensor([1.7311], requires_grad=True) tensor([0.6109], requires_grad=True)
# tensor([1.7317], requires_grad=True) tensor([0.6094], requires_grad=True)
# tensor([1.7324], requires_grad=True) tensor([0.6080], requires_grad=True)
# tensor([1.7330], requires_grad=True) tensor([0.6065], requires_grad=True)
# tensor([1.7337], requires_grad=True) tensor([0.6051], requires_grad=True)
# tensor([1.7343], requires_grad=True) tensor([0.6036], requires_grad=True)
# tensor([1.7350], requires_grad=True) tensor([0.6022], requires_grad=True)
# tensor([1.7356], requires_grad=True) tensor([0.6007], requires_grad=True)
# tensor([1.7363], requires_grad=True) tensor([0.5993], requires_grad=True)
# tensor([1.7369], requires_grad=True) tensor([0.5979], requires_grad=True)
# tensor([1.7376], requires_grad=True) tensor([0.5964], requires_grad=True)
# tensor([1.7382], requires_grad=True) tensor([0.5950], requires_grad=True)
# tensor([1.7388], requires_grad=True) tensor([0.5936], requires_grad=True)
# tensor([1.7395], requires_grad=True) tensor([0.5921], requires_grad=True)
# tensor([1.7401], requires_grad=True) tensor([0.5907], requires_grad=True)
# tensor([1.7407], requires_grad=True) tensor([0.5893], requires_grad=True)
# tensor([1.7414], requires_grad=True) tensor([0.5879], requires_grad=True)
# tensor([1.7420], requires_grad=True) tensor([0.5865], requires_grad=True)
# tensor([1.7426], requires_grad=True) tensor([0.5851], requires_grad=True)
# tensor([1.7432], requires_grad=True) tensor([0.5837], requires_grad=True)
# tensor([1.7438], requires_grad=True) tensor([0.5823], requires_grad=True)
# tensor([1.7445], requires_grad=True) tensor([0.5809], requires_grad=True)
# tensor([1.7451], requires_grad=True) tensor([0.5795], requires_grad=True)
# tensor([1.7457], requires_grad=True) tensor([0.5781], requires_grad=True)
# tensor([1.7463], requires_grad=True) tensor([0.5767], requires_grad=True)
# tensor([1.7469], requires_grad=True) tensor([0.5753], requires_grad=True)
# tensor([1.7475], requires_grad=True) tensor([0.5739], requires_grad=True)
# tensor([1.7481], requires_grad=True) tensor([0.5725], requires_grad=True)
# tensor([1.7487], requires_grad=True) tensor([0.5712], requires_grad=True)
# tensor([1.7493], requires_grad=True) tensor([0.5698], requires_grad=True)
# tensor([1.7499], requires_grad=True) tensor([0.5684], requires_grad=True)
# tensor([1.7505], requires_grad=True) tensor([0.5671], requires_grad=True)
# tensor([1.7511], requires_grad=True) tensor([0.5657], requires_grad=True)
# tensor([1.7517], requires_grad=True) tensor([0.5643], requires_grad=True)
# tensor([1.7523], requires_grad=True) tensor([0.5630], requires_grad=True)
# tensor([1.7529], requires_grad=True) tensor([0.5616], requires_grad=True)
# tensor([1.7535], requires_grad=True) tensor([0.5603], requires_grad=True)
# tensor([1.7541], requires_grad=True) tensor([0.5589], requires_grad=True)
# tensor([1.7547], requires_grad=True) tensor([0.5576], requires_grad=True)
# tensor([1.7553], requires_grad=True) tensor([0.5562], requires_grad=True)
# tensor([1.7559], requires_grad=True) tensor([0.5549], requires_grad=True)
# tensor([1.7565], requires_grad=True) tensor([0.5536], requires_grad=True)
# tensor([1.7571], requires_grad=True) tensor([0.5522], requires_grad=True)
# tensor([1.7577], requires_grad=True) tensor([0.5509], requires_grad=True)
# tensor([1.7582], requires_grad=True) tensor([0.5496], requires_grad=True)
# tensor([1.7588], requires_grad=True) tensor([0.5483], requires_grad=True)
# tensor([1.7594], requires_grad=True) tensor([0.5469], requires_grad=True)
# tensor([1.7600], requires_grad=True) tensor([0.5456], requires_grad=True)
# tensor([1.7606], requires_grad=True) tensor([0.5443], requires_grad=True)
# tensor([1.7611], requires_grad=True) tensor([0.5430], requires_grad=True)
# tensor([1.7617], requires_grad=True) tensor([0.5417], requires_grad=True)
# tensor([1.7623], requires_grad=True) tensor([0.5404], requires_grad=True)
# tensor([1.7628], requires_grad=True) tensor([0.5391], requires_grad=True)
# tensor([1.7634], requires_grad=True) tensor([0.5378], requires_grad=True)
# tensor([1.7640], requires_grad=True) tensor([0.5365], requires_grad=True)
# tensor([1.7646], requires_grad=True) tensor([0.5352], requires_grad=True)
# tensor([1.7651], requires_grad=True) tensor([0.5339], requires_grad=True)
# tensor([1.7657], requires_grad=True) tensor([0.5327], requires_grad=True)
# tensor([1.7662], requires_grad=True) tensor([0.5314], requires_grad=True)
# tensor([1.7668], requires_grad=True) tensor([0.5301], requires_grad=True)
# tensor([1.7674], requires_grad=True) tensor([0.5288], requires_grad=True)
# tensor([1.7679], requires_grad=True) tensor([0.5276], requires_grad=True)
# tensor([1.7685], requires_grad=True) tensor([0.5263], requires_grad=True)
# tensor([1.7690], requires_grad=True) tensor([0.5250], requires_grad=True)
# tensor([1.7696], requires_grad=True) tensor([0.5238], requires_grad=True)
# tensor([1.7702], requires_grad=True) tensor([0.5225], requires_grad=True)
# tensor([1.7707], requires_grad=True) tensor([0.5212], requires_grad=True)
# tensor([1.7713], requires_grad=True) tensor([0.5200], requires_grad=True)
# tensor([1.7718], requires_grad=True) tensor([0.5187], requires_grad=True)
# tensor([1.7724], requires_grad=True) tensor([0.5175], requires_grad=True)
# tensor([1.7729], requires_grad=True) tensor([0.5162], requires_grad=True)
# tensor([1.7734], requires_grad=True) tensor([0.5150], requires_grad=True)
# tensor([1.7740], requires_grad=True) tensor([0.5138], requires_grad=True)
# tensor([1.7745], requires_grad=True) tensor([0.5125], requires_grad=True)
# tensor([1.7751], requires_grad=True) tensor([0.5113], requires_grad=True)
# tensor([1.7756], requires_grad=True) tensor([0.5101], requires_grad=True)
# tensor([1.7762], requires_grad=True) tensor([0.5088], requires_grad=True)
# tensor([1.7767], requires_grad=True) tensor([0.5076], requires_grad=True)
# tensor([1.7772], requires_grad=True) tensor([0.5064], requires_grad=True)
# tensor([1.7778], requires_grad=True) tensor([0.5052], requires_grad=True)
# tensor([1.7783], requires_grad=True) tensor([0.5040], requires_grad=True)
# tensor([1.7788], requires_grad=True) tensor([0.5028], requires_grad=True)
# tensor([1.7794], requires_grad=True) tensor([0.5016], requires_grad=True)
# tensor([1.7799], requires_grad=True) tensor([0.5003], requires_grad=True)
# tensor([1.7804], requires_grad=True) tensor([0.4991], requires_grad=True)
# tensor([1.7810], requires_grad=True) tensor([0.4979], requires_grad=True)
# tensor([1.7815], requires_grad=True) tensor([0.4967], requires_grad=True)
# tensor([1.7820], requires_grad=True) tensor([0.4956], requires_grad=True)
# tensor([1.7825], requires_grad=True) tensor([0.4944], requires_grad=True)
# tensor([1.7831], requires_grad=True) tensor([0.4932], requires_grad=True)
# tensor([1.7836], requires_grad=True) tensor([0.4920], requires_grad=True)
# tensor([1.7841], requires_grad=True) tensor([0.4908], requires_grad=True)
# tensor([1.7846], requires_grad=True) tensor([0.4896], requires_grad=True)
# tensor([1.7851], requires_grad=True) tensor([0.4884], requires_grad=True)
# tensor([1.7856], requires_grad=True) tensor([0.4873], requires_grad=True)
# tensor([1.7862], requires_grad=True) tensor([0.4861], requires_grad=True)
# tensor([1.7867], requires_grad=True) tensor([0.4849], requires_grad=True)
# tensor([1.7872], requires_grad=True) tensor([0.4838], requires_grad=True)
# tensor([1.7877], requires_grad=True) tensor([0.4826], requires_grad=True)
# tensor([1.7882], requires_grad=True) tensor([0.4814], requires_grad=True)
# tensor([1.7887], requires_grad=True) tensor([0.4803], requires_grad=True)
# tensor([1.7892], requires_grad=True) tensor([0.4791], requires_grad=True)
# tensor([1.7897], requires_grad=True) tensor([0.4780], requires_grad=True)
# tensor([1.7902], requires_grad=True) tensor([0.4768], requires_grad=True)
# tensor([1.7907], requires_grad=True) tensor([0.4757], requires_grad=True)
# tensor([1.7912], requires_grad=True) tensor([0.4745], requires_grad=True)
# tensor([1.7918], requires_grad=True) tensor([0.4734], requires_grad=True)
# tensor([1.7923], requires_grad=True) tensor([0.4723], requires_grad=True)
# tensor([1.7928], requires_grad=True) tensor([0.4711], requires_grad=True)
# tensor([1.7932], requires_grad=True) tensor([0.4700], requires_grad=True)
# tensor([1.7937], requires_grad=True) tensor([0.4689], requires_grad=True)
# tensor([1.7942], requires_grad=True) tensor([0.4677], requires_grad=True)
# tensor([1.7947], requires_grad=True) tensor([0.4666], requires_grad=True)
# tensor([1.7952], requires_grad=True) tensor([0.4655], requires_grad=True)
# tensor([1.7957], requires_grad=True) tensor([0.4644], requires_grad=True)
# tensor([1.7962], requires_grad=True) tensor([0.4633], requires_grad=True)
# tensor([1.7967], requires_grad=True) tensor([0.4621], requires_grad=True)
# tensor([1.7972], requires_grad=True) tensor([0.4610], requires_grad=True)
# tensor([1.7977], requires_grad=True) tensor([0.4599], requires_grad=True)
# tensor([1.7982], requires_grad=True) tensor([0.4588], requires_grad=True)
# tensor([1.7987], requires_grad=True) tensor([0.4577], requires_grad=True)
# tensor([1.7991], requires_grad=True) tensor([0.4566], requires_grad=True)
# tensor([1.7996], requires_grad=True) tensor([0.4555], requires_grad=True)
# tensor([1.8001], requires_grad=True) tensor([0.4544], requires_grad=True)
# tensor([1.8006], requires_grad=True) tensor([0.4533], requires_grad=True)
# tensor([1.8011], requires_grad=True) tensor([0.4522], requires_grad=True)
# tensor([1.8015], requires_grad=True) tensor([0.4512], requires_grad=True)
# tensor([1.8020], requires_grad=True) tensor([0.4501], requires_grad=True)
# tensor([1.8025], requires_grad=True) tensor([0.4490], requires_grad=True)
# tensor([1.8030], requires_grad=True) tensor([0.4479], requires_grad=True)
# tensor([1.8034], requires_grad=True) tensor([0.4468], requires_grad=True)
# tensor([1.8039], requires_grad=True) tensor([0.4458], requires_grad=True)
# tensor([1.8044], requires_grad=True) tensor([0.4447], requires_grad=True)
# tensor([1.8049], requires_grad=True) tensor([0.4436], requires_grad=True)
# tensor([1.8053], requires_grad=True) tensor([0.4425], requires_grad=True)
# tensor([1.8058], requires_grad=True) tensor([0.4415], requires_grad=True)
# tensor([1.8063], requires_grad=True) tensor([0.4404], requires_grad=True)
# tensor([1.8067], requires_grad=True) tensor([0.4394], requires_grad=True)
# tensor([1.8072], requires_grad=True) tensor([0.4383], requires_grad=True)
# tensor([1.8077], requires_grad=True) tensor([0.4373], requires_grad=True)
# tensor([1.8081], requires_grad=True) tensor([0.4362], requires_grad=True)
# tensor([1.8086], requires_grad=True) tensor([0.4352], requires_grad=True)
# tensor([1.8090], requires_grad=True) tensor([0.4341], requires_grad=True)
# tensor([1.8095], requires_grad=True) tensor([0.4331], requires_grad=True)
# tensor([1.8100], requires_grad=True) tensor([0.4320], requires_grad=True)
# tensor([1.8104], requires_grad=True) tensor([0.4310], requires_grad=True)
# tensor([1.8109], requires_grad=True) tensor([0.4299], requires_grad=True)
# tensor([1.8113], requires_grad=True) tensor([0.4289], requires_grad=True)
# tensor([1.8118], requires_grad=True) tensor([0.4279], requires_grad=True)
# tensor([1.8122], requires_grad=True) tensor([0.4269], requires_grad=True)
# tensor([1.8127], requires_grad=True) tensor([0.4258], requires_grad=True)
# tensor([1.8131], requires_grad=True) tensor([0.4248], requires_grad=True)
# tensor([1.8136], requires_grad=True) tensor([0.4238], requires_grad=True)
# tensor([1.8140], requires_grad=True) tensor([0.4228], requires_grad=True)
# tensor([1.8145], requires_grad=True) tensor([0.4218], requires_grad=True)
# tensor([1.8149], requires_grad=True) tensor([0.4207], requires_grad=True)
# tensor([1.8154], requires_grad=True) tensor([0.4197], requires_grad=True)
# tensor([1.8158], requires_grad=True) tensor([0.4187], requires_grad=True)
# tensor([1.8162], requires_grad=True) tensor([0.4177], requires_grad=True)
# tensor([1.8167], requires_grad=True) tensor([0.4167], requires_grad=True)
# tensor([1.8171], requires_grad=True) tensor([0.4157], requires_grad=True)
# tensor([1.8176], requires_grad=True) tensor([0.4147], requires_grad=True)
# tensor([1.8180], requires_grad=True) tensor([0.4137], requires_grad=True)
# tensor([1.8184], requires_grad=True) tensor([0.4127], requires_grad=True)
# tensor([1.8189], requires_grad=True) tensor([0.4117], requires_grad=True)
# tensor([1.8193], requires_grad=True) tensor([0.4107], requires_grad=True)
# tensor([1.8198], requires_grad=True) tensor([0.4097], requires_grad=True)
# tensor([1.8202], requires_grad=True) tensor([0.4088], requires_grad=True)
# tensor([1.8206], requires_grad=True) tensor([0.4078], requires_grad=True)
# tensor([1.8210], requires_grad=True) tensor([0.4068], requires_grad=True)
# tensor([1.8215], requires_grad=True) tensor([0.4058], requires_grad=True)
# tensor([1.8219], requires_grad=True) tensor([0.4048], requires_grad=True)
# tensor([1.8223], requires_grad=True) tensor([0.4039], requires_grad=True)
# tensor([1.8228], requires_grad=True) tensor([0.4029], requires_grad=True)
# tensor([1.8232], requires_grad=True) tensor([0.4019], requires_grad=True)
# tensor([1.8236], requires_grad=True) tensor([0.4010], requires_grad=True)
# tensor([1.8240], requires_grad=True) tensor([0.4000], requires_grad=True)
# tensor([1.8245], requires_grad=True) tensor([0.3990], requires_grad=True)
# tensor([1.8249], requires_grad=True) tensor([0.3981], requires_grad=True)
# tensor([1.8253], requires_grad=True) tensor([0.3971], requires_grad=True)
# tensor([1.8257], requires_grad=True) tensor([0.3962], requires_grad=True)
# tensor([1.8261], requires_grad=True) tensor([0.3952], requires_grad=True)
# tensor([1.8266], requires_grad=True) tensor([0.3943], requires_grad=True)
# tensor([1.8270], requires_grad=True) tensor([0.3933], requires_grad=True)
# tensor([1.8274], requires_grad=True) tensor([0.3924], requires_grad=True)
# tensor([1.8278], requires_grad=True) tensor([0.3914], requires_grad=True)
# tensor([1.8282], requires_grad=True) tensor([0.3905], requires_grad=True)
# tensor([1.8286], requires_grad=True) tensor([0.3895], requires_grad=True)
# tensor([1.8290], requires_grad=True) tensor([0.3886], requires_grad=True)
# tensor([1.8295], requires_grad=True) tensor([0.3877], requires_grad=True)
# tensor([1.8299], requires_grad=True) tensor([0.3867], requires_grad=True)
# tensor([1.8303], requires_grad=True) tensor([0.3858], requires_grad=True)
# tensor([1.8307], requires_grad=True) tensor([0.3849], requires_grad=True)
# tensor([1.8311], requires_grad=True) tensor([0.3840], requires_grad=True)
# tensor([1.8315], requires_grad=True) tensor([0.3830], requires_grad=True)
# tensor([1.8319], requires_grad=True) tensor([0.3821], requires_grad=True)
# tensor([1.8323], requires_grad=True) tensor([0.3812], requires_grad=True)
# tensor([1.8327], requires_grad=True) tensor([0.3803], requires_grad=True)
# tensor([1.8331], requires_grad=True) tensor([0.3794], requires_grad=True)
# tensor([1.8335], requires_grad=True) tensor([0.3785], requires_grad=True)
# tensor([1.8339], requires_grad=True) tensor([0.3775], requires_grad=True)
# tensor([1.8343], requires_grad=True) tensor([0.3766], requires_grad=True)
# tensor([1.8347], requires_grad=True) tensor([0.3757], requires_grad=True)
# tensor([1.8351], requires_grad=True) tensor([0.3748], requires_grad=True)
# tensor([1.8355], requires_grad=True) tensor([0.3739], requires_grad=True)
# tensor([1.8359], requires_grad=True) tensor([0.3730], requires_grad=True)
# tensor([1.8363], requires_grad=True) tensor([0.3721], requires_grad=True)
# tensor([1.8367], requires_grad=True) tensor([0.3712], requires_grad=True)
# tensor([1.8371], requires_grad=True) tensor([0.3703], requires_grad=True)
# tensor([1.8375], requires_grad=True) tensor([0.3695], requires_grad=True)
# tensor([1.8379], requires_grad=True) tensor([0.3686], requires_grad=True)
# tensor([1.8383], requires_grad=True) tensor([0.3677], requires_grad=True)
# tensor([1.8386], requires_grad=True) tensor([0.3668], requires_grad=True)
# tensor([1.8390], requires_grad=True) tensor([0.3659], requires_grad=True)
# tensor([1.8394], requires_grad=True) tensor([0.3650], requires_grad=True)
# tensor([1.8398], requires_grad=True) tensor([0.3642], requires_grad=True)
# tensor([1.8402], requires_grad=True) tensor([0.3633], requires_grad=True)
# tensor([1.8406], requires_grad=True) tensor([0.3624], requires_grad=True)
# tensor([1.8410], requires_grad=True) tensor([0.3615], requires_grad=True)
# tensor([1.8413], requires_grad=True) tensor([0.3607], requires_grad=True)
# tensor([1.8417], requires_grad=True) tensor([0.3598], requires_grad=True)
# tensor([1.8421], requires_grad=True) tensor([0.3589], requires_grad=True)
# tensor([1.8425], requires_grad=True) tensor([0.3581], requires_grad=True)
# tensor([1.8429], requires_grad=True) tensor([0.3572], requires_grad=True)
# tensor([1.8432], requires_grad=True) tensor([0.3564], requires_grad=True)
# tensor([1.8436], requires_grad=True) tensor([0.3555], requires_grad=True)
# tensor([1.8440], requires_grad=True) tensor([0.3546], requires_grad=True)
# tensor([1.8444], requires_grad=True) tensor([0.3538], requires_grad=True)
# tensor([1.8447], requires_grad=True) tensor([0.3529], requires_grad=True)
# tensor([1.8451], requires_grad=True) tensor([0.3521], requires_grad=True)
# tensor([1.8455], requires_grad=True) tensor([0.3512], requires_grad=True)
# tensor([1.8459], requires_grad=True) tensor([0.3504], requires_grad=True)
# tensor([1.8462], requires_grad=True) tensor([0.3496], requires_grad=True)
# tensor([1.8466], requires_grad=True) tensor([0.3487], requires_grad=True)
# tensor([1.8470], requires_grad=True) tensor([0.3479], requires_grad=True)
# tensor([1.8473], requires_grad=True) tensor([0.3470], requires_grad=True)
# tensor([1.8477], requires_grad=True) tensor([0.3462], requires_grad=True)
# tensor([1.8481], requires_grad=True) tensor([0.3454], requires_grad=True)
# tensor([1.8484], requires_grad=True) tensor([0.3446], requires_grad=True)
# tensor([1.8488], requires_grad=True) tensor([0.3437], requires_grad=True)
# tensor([1.8492], requires_grad=True) tensor([0.3429], requires_grad=True)
# tensor([1.8495], requires_grad=True) tensor([0.3421], requires_grad=True)
# tensor([1.8499], requires_grad=True) tensor([0.3412], requires_grad=True)
# tensor([1.8502], requires_grad=True) tensor([0.3404], requires_grad=True)
# tensor([1.8506], requires_grad=True) tensor([0.3396], requires_grad=True)
# tensor([1.8510], requires_grad=True) tensor([0.3388], requires_grad=True)
# tensor([1.8513], requires_grad=True) tensor([0.3380], requires_grad=True)
# tensor([1.8517], requires_grad=True) tensor([0.3372], requires_grad=True)
# tensor([1.8520], requires_grad=True) tensor([0.3364], requires_grad=True)
# tensor([1.8524], requires_grad=True) tensor([0.3355], requires_grad=True)
# tensor([1.8527], requires_grad=True) tensor([0.3347], requires_grad=True)
# tensor([1.8531], requires_grad=True) tensor([0.3339], requires_grad=True)
# tensor([1.8535], requires_grad=True) tensor([0.3331], requires_grad=True)
# tensor([1.8538], requires_grad=True) tensor([0.3323], requires_grad=True)
# tensor([1.8542], requires_grad=True) tensor([0.3315], requires_grad=True)
# tensor([1.8545], requires_grad=True) tensor([0.3307], requires_grad=True)
# tensor([1.8549], requires_grad=True) tensor([0.3299], requires_grad=True)
# tensor([1.8552], requires_grad=True) tensor([0.3291], requires_grad=True)
# tensor([1.8556], requires_grad=True) tensor([0.3284], requires_grad=True)
# tensor([1.8559], requires_grad=True) tensor([0.3276], requires_grad=True)
# tensor([1.8562], requires_grad=True) tensor([0.3268], requires_grad=True)
# tensor([1.8566], requires_grad=True) tensor([0.3260], requires_grad=True)
# tensor([1.8569], requires_grad=True) tensor([0.3252], requires_grad=True)
# tensor([1.8573], requires_grad=True) tensor([0.3244], requires_grad=True)
# tensor([1.8576], requires_grad=True) tensor([0.3237], requires_grad=True)
# tensor([1.8580], requires_grad=True) tensor([0.3229], requires_grad=True)
# tensor([1.8583], requires_grad=True) tensor([0.3221], requires_grad=True)
# tensor([1.8587], requires_grad=True) tensor([0.3213], requires_grad=True)
# tensor([1.8590], requires_grad=True) tensor([0.3205], requires_grad=True)
# tensor([1.8593], requires_grad=True) tensor([0.3198], requires_grad=True)
# tensor([1.8597], requires_grad=True) tensor([0.3190], requires_grad=True)
# tensor([1.8600], requires_grad=True) tensor([0.3182], requires_grad=True)
# tensor([1.8603], requires_grad=True) tensor([0.3175], requires_grad=True)
# tensor([1.8607], requires_grad=True) tensor([0.3167], requires_grad=True)
# tensor([1.8610], requires_grad=True) tensor([0.3160], requires_grad=True)
# tensor([1.8613], requires_grad=True) tensor([0.3152], requires_grad=True)
# tensor([1.8617], requires_grad=True) tensor([0.3144], requires_grad=True)
# tensor([1.8620], requires_grad=True) tensor([0.3137], requires_grad=True)
# tensor([1.8623], requires_grad=True) tensor([0.3129], requires_grad=True)
# tensor([1.8627], requires_grad=True) tensor([0.3122], requires_grad=True)
# tensor([1.8630], requires_grad=True) tensor([0.3114], requires_grad=True)
# tensor([1.8633], requires_grad=True) tensor([0.3107], requires_grad=True)
# tensor([1.8637], requires_grad=True) tensor([0.3099], requires_grad=True)
# tensor([1.8640], requires_grad=True) tensor([0.3092], requires_grad=True)
# tensor([1.8643], requires_grad=True) tensor([0.3084], requires_grad=True)
# tensor([1.8646], requires_grad=True) tensor([0.3077], requires_grad=True)
# tensor([1.8650], requires_grad=True) tensor([0.3070], requires_grad=True)
# tensor([1.8653], requires_grad=True) tensor([0.3062], requires_grad=True)
# tensor([1.8656], requires_grad=True) tensor([0.3055], requires_grad=True)
# tensor([1.8659], requires_grad=True) tensor([0.3048], requires_grad=True)
# tensor([1.8663], requires_grad=True) tensor([0.3040], requires_grad=True)
# tensor([1.8666], requires_grad=True) tensor([0.3033], requires_grad=True)
# tensor([1.8669], requires_grad=True) tensor([0.3026], requires_grad=True)
# tensor([1.8672], requires_grad=True) tensor([0.3018], requires_grad=True)
# tensor([1.8675], requires_grad=True) tensor([0.3011], requires_grad=True)
# tensor([1.8679], requires_grad=True) tensor([0.3004], requires_grad=True)
# tensor([1.8682], requires_grad=True) tensor([0.2997], requires_grad=True)
# tensor([1.8685], requires_grad=True) tensor([0.2989], requires_grad=True)
# tensor([1.8688], requires_grad=True) tensor([0.2982], requires_grad=True)
# tensor([1.8691], requires_grad=True) tensor([0.2975], requires_grad=True)
# tensor([1.8694], requires_grad=True) tensor([0.2968], requires_grad=True)
# tensor([1.8698], requires_grad=True) tensor([0.2961], requires_grad=True)
# tensor([1.8701], requires_grad=True) tensor([0.2954], requires_grad=True)
# tensor([1.8704], requires_grad=True) tensor([0.2947], requires_grad=True)
# tensor([1.8707], requires_grad=True) tensor([0.2939], requires_grad=True)
# tensor([1.8710], requires_grad=True) tensor([0.2932], requires_grad=True)
# tensor([1.8713], requires_grad=True) tensor([0.2925], requires_grad=True)
# tensor([1.8716], requires_grad=True) tensor([0.2918], requires_grad=True)
# tensor([1.8719], requires_grad=True) tensor([0.2911], requires_grad=True)
# tensor([1.8722], requires_grad=True) tensor([0.2904], requires_grad=True)
# tensor([1.8725], requires_grad=True) tensor([0.2897], requires_grad=True)
# tensor([1.8729], requires_grad=True) tensor([0.2890], requires_grad=True)
# tensor([1.8732], requires_grad=True) tensor([0.2883], requires_grad=True)
# tensor([1.8735], requires_grad=True) tensor([0.2876], requires_grad=True)
# tensor([1.8738], requires_grad=True) tensor([0.2870], requires_grad=True)
# tensor([1.8741], requires_grad=True) tensor([0.2863], requires_grad=True)
# tensor([1.8744], requires_grad=True) tensor([0.2856], requires_grad=True)
# tensor([1.8747], requires_grad=True) tensor([0.2849], requires_grad=True)
# tensor([1.8750], requires_grad=True) tensor([0.2842], requires_grad=True)
# tensor([1.8753], requires_grad=True) tensor([0.2835], requires_grad=True)
# tensor([1.8756], requires_grad=True) tensor([0.2828], requires_grad=True)
# tensor([1.8759], requires_grad=True) tensor([0.2822], requires_grad=True)
# tensor([1.8762], requires_grad=True) tensor([0.2815], requires_grad=True)
# tensor([1.8765], requires_grad=True) tensor([0.2808], requires_grad=True)
# tensor([1.8768], requires_grad=True) tensor([0.2801], requires_grad=True)
# tensor([1.8771], requires_grad=True) tensor([0.2795], requires_grad=True)
# tensor([1.8774], requires_grad=True) tensor([0.2788], requires_grad=True)
# tensor([1.8777], requires_grad=True) tensor([0.2781], requires_grad=True)
# tensor([1.8780], requires_grad=True) tensor([0.2774], requires_grad=True)
# tensor([1.8782], requires_grad=True) tensor([0.2768], requires_grad=True)
# tensor([1.8785], requires_grad=True) tensor([0.2761], requires_grad=True)
# tensor([1.8788], requires_grad=True) tensor([0.2754], requires_grad=True)
# tensor([1.8791], requires_grad=True) tensor([0.2748], requires_grad=True)
# tensor([1.8794], requires_grad=True) tensor([0.2741], requires_grad=True)
# tensor([1.8797], requires_grad=True) tensor([0.2735], requires_grad=True)
# tensor([1.8800], requires_grad=True) tensor([0.2728], requires_grad=True)
# tensor([1.8803], requires_grad=True) tensor([0.2722], requires_grad=True)
# tensor([1.8806], requires_grad=True) tensor([0.2715], requires_grad=True)
# tensor([1.8809], requires_grad=True) tensor([0.2708], requires_grad=True)
# tensor([1.8811], requires_grad=True) tensor([0.2702], requires_grad=True)
# tensor([1.8814], requires_grad=True) tensor([0.2695], requires_grad=True)
# tensor([1.8817], requires_grad=True) tensor([0.2689], requires_grad=True)
# tensor([1.8820], requires_grad=True) tensor([0.2683], requires_grad=True)
# tensor([1.8823], requires_grad=True) tensor([0.2676], requires_grad=True)
# tensor([1.8826], requires_grad=True) tensor([0.2670], requires_grad=True)
# tensor([1.8828], requires_grad=True) tensor([0.2663], requires_grad=True)
# tensor([1.8831], requires_grad=True) tensor([0.2657], requires_grad=True)
# tensor([1.8834], requires_grad=True) tensor([0.2650], requires_grad=True)
# tensor([1.8837], requires_grad=True) tensor([0.2644], requires_grad=True)
# tensor([1.8840], requires_grad=True) tensor([0.2638], requires_grad=True)
# tensor([1.8842], requires_grad=True) tensor([0.2631], requires_grad=True)
# tensor([1.8845], requires_grad=True) tensor([0.2625], requires_grad=True)
# tensor([1.8848], requires_grad=True) tensor([0.2619], requires_grad=True)
# tensor([1.8851], requires_grad=True) tensor([0.2612], requires_grad=True)
# tensor([1.8854], requires_grad=True) tensor([0.2606], requires_grad=True)
# tensor([1.8856], requires_grad=True) tensor([0.2600], requires_grad=True)
# tensor([1.8859], requires_grad=True) tensor([0.2594], requires_grad=True)
# tensor([1.8862], requires_grad=True) tensor([0.2587], requires_grad=True)
# tensor([1.8865], requires_grad=True) tensor([0.2581], requires_grad=True)
# tensor([1.8867], requires_grad=True) tensor([0.2575], requires_grad=True)
# tensor([1.8870], requires_grad=True) tensor([0.2569], requires_grad=True)
# tensor([1.8873], requires_grad=True) tensor([0.2563], requires_grad=True)
# tensor([1.8875], requires_grad=True) tensor([0.2556], requires_grad=True)
# tensor([1.8878], requires_grad=True) tensor([0.2550], requires_grad=True)
# tensor([1.8881], requires_grad=True) tensor([0.2544], requires_grad=True)
# tensor([1.8883], requires_grad=True) tensor([0.2538], requires_grad=True)
# tensor([1.8886], requires_grad=True) tensor([0.2532], requires_grad=True)
# tensor([1.8889], requires_grad=True) tensor([0.2526], requires_grad=True)
# tensor([1.8892], requires_grad=True) tensor([0.2520], requires_grad=True)
# tensor([1.8894], requires_grad=True) tensor([0.2514], requires_grad=True)
# tensor([1.8897], requires_grad=True) tensor([0.2508], requires_grad=True)
# tensor([1.8900], requires_grad=True) tensor([0.2502], requires_grad=True)
# tensor([1.8902], requires_grad=True) tensor([0.2496], requires_grad=True)
# tensor([1.8905], requires_grad=True) tensor([0.2490], requires_grad=True)
# tensor([1.8907], requires_grad=True) tensor([0.2484], requires_grad=True)
# tensor([1.8910], requires_grad=True) tensor([0.2478], requires_grad=True)
# tensor([1.8913], requires_grad=True) tensor([0.2472], requires_grad=True)
# tensor([1.8915], requires_grad=True) tensor([0.2466], requires_grad=True)
# tensor([1.8918], requires_grad=True) tensor([0.2460], requires_grad=True)
# tensor([1.8920], requires_grad=True) tensor([0.2454], requires_grad=True)
# tensor([1.8923], requires_grad=True) tensor([0.2448], requires_grad=True)
# tensor([1.8926], requires_grad=True) tensor([0.2442], requires_grad=True)
# tensor([1.8928], requires_grad=True) tensor([0.2436], requires_grad=True)
# tensor([1.8931], requires_grad=True) tensor([0.2430], requires_grad=True)
# tensor([1.8933], requires_grad=True) tensor([0.2425], requires_grad=True)
# tensor([1.8936], requires_grad=True) tensor([0.2419], requires_grad=True)
# tensor([1.8939], requires_grad=True) tensor([0.2413], requires_grad=True)
# tensor([1.8941], requires_grad=True) tensor([0.2407], requires_grad=True)
# tensor([1.8944], requires_grad=True) tensor([0.2401], requires_grad=True)
# tensor([1.8946], requires_grad=True) tensor([0.2396], requires_grad=True)
# tensor([1.8949], requires_grad=True) tensor([0.2390], requires_grad=True)
# tensor([1.8951], requires_grad=True) tensor([0.2384], requires_grad=True)
# tensor([1.8954], requires_grad=True) tensor([0.2378], requires_grad=True)
# tensor([1.8956], requires_grad=True) tensor([0.2373], requires_grad=True)
# tensor([1.8959], requires_grad=True) tensor([0.2367], requires_grad=True)
# tensor([1.8961], requires_grad=True) tensor([0.2361], requires_grad=True)
# tensor([1.8964], requires_grad=True) tensor([0.2356], requires_grad=True)
# tensor([1.8966], requires_grad=True) tensor([0.2350], requires_grad=True)
# tensor([1.8969], requires_grad=True) tensor([0.2344], requires_grad=True)
# tensor([1.8971], requires_grad=True) tensor([0.2339], requires_grad=True)
# tensor([1.8974], requires_grad=True) tensor([0.2333], requires_grad=True)
# tensor([1.8976], requires_grad=True) tensor([0.2327], requires_grad=True)
# tensor([1.8979], requires_grad=True) tensor([0.2322], requires_grad=True)
# tensor([1.8981], requires_grad=True) tensor([0.2316], requires_grad=True)
# tensor([1.8984], requires_grad=True) tensor([0.2311], requires_grad=True)
# tensor([1.8986], requires_grad=True) tensor([0.2305], requires_grad=True)
# tensor([1.8988], requires_grad=True) tensor([0.2300], requires_grad=True)
# tensor([1.8991], requires_grad=True) tensor([0.2294], requires_grad=True)
# tensor([1.8993], requires_grad=True) tensor([0.2289], requires_grad=True)
# tensor([1.8996], requires_grad=True) tensor([0.2283], requires_grad=True)
# tensor([1.8998], requires_grad=True) tensor([0.2278], requires_grad=True)
# tensor([1.9001], requires_grad=True) tensor([0.2272], requires_grad=True)
# tensor([1.9003], requires_grad=True) tensor([0.2267], requires_grad=True)
# tensor([1.9005], requires_grad=True) tensor([0.2261], requires_grad=True)
# tensor([1.9008], requires_grad=True) tensor([0.2256], requires_grad=True)
# tensor([1.9010], requires_grad=True) tensor([0.2250], requires_grad=True)
# tensor([1.9012], requires_grad=True) tensor([0.2245], requires_grad=True)
# tensor([1.9015], requires_grad=True) tensor([0.2239], requires_grad=True)
# tensor([1.9017], requires_grad=True) tensor([0.2234], requires_grad=True)
# tensor([1.9020], requires_grad=True) tensor([0.2229], requires_grad=True)
# tensor([1.9022], requires_grad=True) tensor([0.2223], requires_grad=True)
# tensor([1.9024], requires_grad=True) tensor([0.2218], requires_grad=True)
# tensor([1.9027], requires_grad=True) tensor([0.2213], requires_grad=True)
# tensor([1.9029], requires_grad=True) tensor([0.2207], requires_grad=True)
# tensor([1.9031], requires_grad=True) tensor([0.2202], requires_grad=True)
# tensor([1.9034], requires_grad=True) tensor([0.2197], requires_grad=True)
# tensor([1.9036], requires_grad=True) tensor([0.2191], requires_grad=True)
# tensor([1.9038], requires_grad=True) tensor([0.2186], requires_grad=True)
# tensor([1.9041], requires_grad=True) tensor([0.2181], requires_grad=True)
# tensor([1.9043], requires_grad=True) tensor([0.2176], requires_grad=True)
# tensor([1.9045], requires_grad=True) tensor([0.2171], requires_grad=True)
# tensor([1.9047], requires_grad=True) tensor([0.2165], requires_grad=True)
# tensor([1.9050], requires_grad=True) tensor([0.2160], requires_grad=True)
# tensor([1.9052], requires_grad=True) tensor([0.2155], requires_grad=True)
# tensor([1.9054], requires_grad=True) tensor([0.2150], requires_grad=True)
# tensor([1.9057], requires_grad=True) tensor([0.2145], requires_grad=True)
# tensor([1.9059], requires_grad=True) tensor([0.2139], requires_grad=True)
# tensor([1.9061], requires_grad=True) tensor([0.2134], requires_grad=True)
# tensor([1.9063], requires_grad=True) tensor([0.2129], requires_grad=True)
# tensor([1.9066], requires_grad=True) tensor([0.2124], requires_grad=True)
# tensor([1.9068], requires_grad=True) tensor([0.2119], requires_grad=True)
# tensor([1.9070], requires_grad=True) tensor([0.2114], requires_grad=True)
# tensor([1.9072], requires_grad=True) tensor([0.2109], requires_grad=True)
# tensor([1.9075], requires_grad=True) tensor([0.2104], requires_grad=True)
# tensor([1.9077], requires_grad=True) tensor([0.2099], requires_grad=True)
# tensor([1.9079], requires_grad=True) tensor([0.2094], requires_grad=True)
# tensor([1.9081], requires_grad=True) tensor([0.2089], requires_grad=True)
# tensor([1.9083], requires_grad=True) tensor([0.2083], requires_grad=True)
# tensor([1.9086], requires_grad=True) tensor([0.2078], requires_grad=True)
# tensor([1.9088], requires_grad=True) tensor([0.2073], requires_grad=True)
# tensor([1.9090], requires_grad=True) tensor([0.2068], requires_grad=True)
# tensor([1.9092], requires_grad=True) tensor([0.2064], requires_grad=True)
# tensor([1.9094], requires_grad=True) tensor([0.2059], requires_grad=True)
# tensor([1.9097], requires_grad=True) tensor([0.2054], requires_grad=True)
# tensor([1.9099], requires_grad=True) tensor([0.2049], requires_grad=True)
# tensor([1.9101], requires_grad=True) tensor([0.2044], requires_grad=True)
# tensor([1.9103], requires_grad=True) tensor([0.2039], requires_grad=True)
# tensor([1.9105], requires_grad=True) tensor([0.2034], requires_grad=True)
# tensor([1.9107], requires_grad=True) tensor([0.2029], requires_grad=True)
# tensor([1.9110], requires_grad=True) tensor([0.2024], requires_grad=True)
# tensor([1.9112], requires_grad=True) tensor([0.2019], requires_grad=True)
# tensor([1.9114], requires_grad=True) tensor([0.2014], requires_grad=True)
# tensor([1.9116], requires_grad=True) tensor([0.2010], requires_grad=True)
# tensor([1.9118], requires_grad=True) tensor([0.2005], requires_grad=True)
# tensor([1.9120], requires_grad=True) tensor([0.2000], requires_grad=True)
# tensor([1.9122], requires_grad=True) tensor([0.1995], requires_grad=True)
# tensor([1.9124], requires_grad=True) tensor([0.1990], requires_grad=True)
# tensor([1.9127], requires_grad=True) tensor([0.1986], requires_grad=True)
# tensor([1.9129], requires_grad=True) tensor([0.1981], requires_grad=True)
# tensor([1.9131], requires_grad=True) tensor([0.1976], requires_grad=True)
# tensor([1.9133], requires_grad=True) tensor([0.1971], requires_grad=True)
# tensor([1.9135], requires_grad=True) tensor([0.1967], requires_grad=True)
# tensor([1.9137], requires_grad=True) tensor([0.1962], requires_grad=True)
# tensor([1.9139], requires_grad=True) tensor([0.1957], requires_grad=True)
# tensor([1.9141], requires_grad=True) tensor([0.1952], requires_grad=True)
# tensor([1.9143], requires_grad=True) tensor([0.1948], requires_grad=True)
# tensor([1.9145], requires_grad=True) tensor([0.1943], requires_grad=True)
# tensor([1.9147], requires_grad=True) tensor([0.1938], requires_grad=True)
# tensor([1.9149], requires_grad=True) tensor([0.1934], requires_grad=True)
# tensor([1.9151], requires_grad=True) tensor([0.1929], requires_grad=True)
# tensor([1.9153], requires_grad=True) tensor([0.1924], requires_grad=True)
# tensor([1.9155], requires_grad=True) tensor([0.1920], requires_grad=True)
# tensor([1.9158], requires_grad=True) tensor([0.1915], requires_grad=True)
# tensor([1.9160], requires_grad=True) tensor([0.1911], requires_grad=True)
# tensor([1.9162], requires_grad=True) tensor([0.1906], requires_grad=True)
# tensor([1.9164], requires_grad=True) tensor([0.1901], requires_grad=True)
# tensor([1.9166], requires_grad=True) tensor([0.1897], requires_grad=True)
# tensor([1.9168], requires_grad=True) tensor([0.1892], requires_grad=True)
# tensor([1.9170], requires_grad=True) tensor([0.1888], requires_grad=True)
# tensor([1.9172], requires_grad=True) tensor([0.1883], requires_grad=True)
# tensor([1.9174], requires_grad=True) tensor([0.1879], requires_grad=True)
# tensor([1.9176], requires_grad=True) tensor([0.1874], requires_grad=True)
# tensor([1.9178], requires_grad=True) tensor([0.1870], requires_grad=True)
# tensor([1.9180], requires_grad=True) tensor([0.1865], requires_grad=True)
# tensor([1.9182], requires_grad=True) tensor([0.1861], requires_grad=True)
# tensor([1.9183], requires_grad=True) tensor([0.1856], requires_grad=True)
# tensor([1.9185], requires_grad=True) tensor([0.1852], requires_grad=True)
# tensor([1.9187], requires_grad=True) tensor([0.1847], requires_grad=True)
# tensor([1.9189], requires_grad=True) tensor([0.1843], requires_grad=True)
# tensor([1.9191], requires_grad=True) tensor([0.1838], requires_grad=True)
# tensor([1.9193], requires_grad=True) tensor([0.1834], requires_grad=True)
# tensor([1.9195], requires_grad=True) tensor([0.1830], requires_grad=True)
# tensor([1.9197], requires_grad=True) tensor([0.1825], requires_grad=True)
# tensor([1.9199], requires_grad=True) tensor([0.1821], requires_grad=True)
# tensor([1.9201], requires_grad=True) tensor([0.1816], requires_grad=True)
# tensor([1.9203], requires_grad=True) tensor([0.1812], requires_grad=True)
# tensor([1.9205], requires_grad=True) tensor([0.1808], requires_grad=True)
# tensor([1.9207], requires_grad=True) tensor([0.1803], requires_grad=True)
# tensor([1.9209], requires_grad=True) tensor([0.1799], requires_grad=True)
# tensor([1.9211], requires_grad=True) tensor([0.1795], requires_grad=True)
# tensor([1.9212], requires_grad=True) tensor([0.1790], requires_grad=True)
# tensor([1.9214], requires_grad=True) tensor([0.1786], requires_grad=True)
# tensor([1.9216], requires_grad=True) tensor([0.1782], requires_grad=True)
# tensor([1.9218], requires_grad=True) tensor([0.1777], requires_grad=True)
# tensor([1.9220], requires_grad=True) tensor([0.1773], requires_grad=True)
# tensor([1.9222], requires_grad=True) tensor([0.1769], requires_grad=True)
# tensor([1.9224], requires_grad=True) tensor([0.1765], requires_grad=True)
# tensor([1.9226], requires_grad=True) tensor([0.1760], requires_grad=True)
# tensor([1.9227], requires_grad=True) tensor([0.1756], requires_grad=True)
# tensor([1.9229], requires_grad=True) tensor([0.1752], requires_grad=True)
# tensor([1.9231], requires_grad=True) tensor([0.1748], requires_grad=True)
# tensor([1.9233], requires_grad=True) tensor([0.1744], requires_grad=True)
# tensor([1.9235], requires_grad=True) tensor([0.1739], requires_grad=True)
# tensor([1.9237], requires_grad=True) tensor([0.1735], requires_grad=True)
# tensor([1.9239], requires_grad=True) tensor([0.1731], requires_grad=True)
# tensor([1.9240], requires_grad=True) tensor([0.1727], requires_grad=True)
# tensor([1.9242], requires_grad=True) tensor([0.1723], requires_grad=True)
# tensor([1.9244], requires_grad=True) tensor([0.1719], requires_grad=True)
# tensor([1.9246], requires_grad=True) tensor([0.1714], requires_grad=True)
# tensor([1.9248], requires_grad=True) tensor([0.1710], requires_grad=True)
# tensor([1.9249], requires_grad=True) tensor([0.1706], requires_grad=True)
# tensor([1.9251], requires_grad=True) tensor([0.1702], requires_grad=True)
# tensor([1.9253], requires_grad=True) tensor([0.1698], requires_grad=True)
# tensor([1.9255], requires_grad=True) tensor([0.1694], requires_grad=True)
# tensor([1.9257], requires_grad=True) tensor([0.1690], requires_grad=True)
# tensor([1.9258], requires_grad=True) tensor([0.1686], requires_grad=True)
# tensor([1.9260], requires_grad=True) tensor([0.1682], requires_grad=True)
# tensor([1.9262], requires_grad=True) tensor([0.1678], requires_grad=True)
# tensor([1.9264], requires_grad=True) tensor([0.1674], requires_grad=True)
# tensor([1.9266], requires_grad=True) tensor([0.1670], requires_grad=True)
# tensor([1.9267], requires_grad=True) tensor([0.1666], requires_grad=True)
# tensor([1.9269], requires_grad=True) tensor([0.1662], requires_grad=True)
# tensor([1.9271], requires_grad=True) tensor([0.1658], requires_grad=True)
# tensor([1.9273], requires_grad=True) tensor([0.1654], requires_grad=True)
# tensor([1.9274], requires_grad=True) tensor([0.1650], requires_grad=True)
# tensor([1.9276], requires_grad=True) tensor([0.1646], requires_grad=True)
# tensor([1.9278], requires_grad=True) tensor([0.1642], requires_grad=True)
# tensor([1.9280], requires_grad=True) tensor([0.1638], requires_grad=True)
# tensor([1.9281], requires_grad=True) tensor([0.1634], requires_grad=True)
# tensor([1.9283], requires_grad=True) tensor([0.1630], requires_grad=True)
# tensor([1.9285], requires_grad=True) tensor([0.1626], requires_grad=True)
# tensor([1.9286], requires_grad=True) tensor([0.1622], requires_grad=True)
# tensor([1.9288], requires_grad=True) tensor([0.1618], requires_grad=True)
# tensor([1.9290], requires_grad=True) tensor([0.1614], requires_grad=True)
# tensor([1.9292], requires_grad=True) tensor([0.1610], requires_grad=True)
# tensor([1.9293], requires_grad=True) tensor([0.1607], requires_grad=True)
# tensor([1.9295], requires_grad=True) tensor([0.1603], requires_grad=True)
# tensor([1.9297], requires_grad=True) tensor([0.1599], requires_grad=True)
# tensor([1.9298], requires_grad=True) tensor([0.1595], requires_grad=True)
# tensor([1.9300], requires_grad=True) tensor([0.1591], requires_grad=True)
# tensor([1.9302], requires_grad=True) tensor([0.1587], requires_grad=True)
# tensor([1.9303], requires_grad=True) tensor([0.1584], requires_grad=True)
# tensor([1.9305], requires_grad=True) tensor([0.1580], requires_grad=True)
# tensor([1.9307], requires_grad=True) tensor([0.1576], requires_grad=True)
# tensor([1.9308], requires_grad=True) tensor([0.1572], requires_grad=True)
# tensor([1.9310], requires_grad=True) tensor([0.1568], requires_grad=True)
# tensor([1.9312], requires_grad=True) tensor([0.1565], requires_grad=True)
# tensor([1.9313], requires_grad=True) tensor([0.1561], requires_grad=True)
# tensor([1.9315], requires_grad=True) tensor([0.1557], requires_grad=True)
# tensor([1.9317], requires_grad=True) tensor([0.1553], requires_grad=True)
# tensor([1.9318], requires_grad=True) tensor([0.1550], requires_grad=True)
# ...
# tensor([1.9510], requires_grad=True) tensor([0.1114], requires_grad=True)
# tensor([1.9511], requires_grad=True) tensor([0.1112], requires_grad=True)
# tensor([1.9512], requires_grad=True) tensor([0.1109], requires_grad=True)
# tensor([1.9513], requires_grad=True) tensor([0.1106], requires_grad=True)
# tensor([1.9514], requires_grad=True) tensor([0.1104], requires_grad=True)
# tensor([1.9516], requires_grad=True) tensor([0.1101], requires_grad=True)
# tensor([1.9517], requires_grad=True) tensor([0.1098], requires_grad=True)
# tensor([1.9518], requires_grad=True) tensor([0.1096], requires_grad=True)
# tensor([1.9519], requires_grad=True) tensor([0.1093], requires_grad=True)
# tensor([1.9520], requires_grad=True) tensor([0.1090], requires_grad=True)
# tensor([1.9521], requires_grad=True) tensor([0.1088], requires_grad=True)
# tensor([1.9523], requires_grad=True) tensor([0.1085], requires_grad=True)
# tensor([1.9524], requires_grad=True) tensor([0.1083], requires_grad=True)
# tensor([1.9525], requires_grad=True) tensor([0.1080], requires_grad=True)
# tensor([1.9526], requires_grad=True) tensor([0.1077], requires_grad=True)
# tensor([1.9527], requires_grad=True) tensor([0.1075], requires_grad=True)
# tensor([1.9528], requires_grad=True) tensor([0.1072], requires_grad=True)
# tensor([1.9529], requires_grad=True) tensor([0.1070], requires_grad=True)
# tensor([1.9531], requires_grad=True) tensor([0.1067], requires_grad=True)
# tensor([1.9532], requires_grad=True) tensor([0.1065], requires_grad=True)
# tensor([1.9533], requires_grad=True) tensor([0.1062], requires_grad=True)
# tensor([1.9534], requires_grad=True) tensor([0.1059], requires_grad=True)
# tensor([1.9535], requires_grad=True) tensor([0.1057], requires_grad=True)
# tensor([1.9536], requires_grad=True) tensor([0.1054], requires_grad=True)
# tensor([1.9537], requires_grad=True) tensor([0.1052], requires_grad=True)
# tensor([1.9538], requires_grad=True) tensor([0.1049], requires_grad=True)
# tensor([1.9540], requires_grad=True) tensor([0.1047], requires_grad=True)
# tensor([1.9541], requires_grad=True) tensor([0.1044], requires_grad=True)
# tensor([1.9542], requires_grad=True) tensor([0.1042], requires_grad=True)
# tensor([1.9543], requires_grad=True) tensor([0.1039], requires_grad=True)
# tensor([1.9544], requires_grad=True) tensor([0.1037], requires_grad=True)
# tensor([1.9545], requires_grad=True) tensor([0.1034], requires_grad=True)
# tensor([1.9546], requires_grad=True) tensor([0.1032], requires_grad=True)
# tensor([1.9547], requires_grad=True) tensor([0.1029], requires_grad=True)
# tensor([1.9548], requires_grad=True) tensor([0.1027], requires_grad=True)
# tensor([1.9549], requires_grad=True) tensor([0.1024], requires_grad=True)
# tensor([1.9550], requires_grad=True) tensor([0.1022], requires_grad=True)
# tensor([1.9552], requires_grad=True) tensor([0.1019], requires_grad=True)
# tensor([1.9553], requires_grad=True) tensor([0.1017], requires_grad=True)
# tensor([1.9554], requires_grad=True) tensor([0.1015], requires_grad=True)
# tensor([1.9555], requires_grad=True) tensor([0.1012], requires_grad=True)
# tensor([1.9556], requires_grad=True) tensor([0.1010], requires_grad=True)
# tensor([1.9557], requires_grad=True) tensor([0.1007], requires_grad=True)
# tensor([1.9558], requires_grad=True) tensor([0.1005], requires_grad=True)
# tensor([1.9559], requires_grad=True) tensor([0.1002], requires_grad=True)
# tensor([1.9560], requires_grad=True) tensor([0.1000], requires_grad=True)
# tensor([1.9561], requires_grad=True) tensor([0.0998], requires_grad=True)
# tensor([1.9562], requires_grad=True) tensor([0.0995], requires_grad=True)
# tensor([1.9563], requires_grad=True) tensor([0.0993], requires_grad=True)
# tensor([1.9564], requires_grad=True) tensor([0.0990], requires_grad=True)
# tensor([1.9565], requires_grad=True) tensor([0.0988], requires_grad=True)
# tensor([1.9566], requires_grad=True) tensor([0.0986], requires_grad=True)
# tensor([1.9567], requires_grad=True) tensor([0.0983], requires_grad=True)
# tensor([1.9569], requires_grad=True) tensor([0.0981], requires_grad=True)
# tensor([1.9570], requires_grad=True) tensor([0.0979], requires_grad=True)
# tensor([1.9571], requires_grad=True) tensor([0.0976], requires_grad=True)
# tensor([1.9572], requires_grad=True) tensor([0.0974], requires_grad=True)
# tensor([1.9573], requires_grad=True) tensor([0.0971], requires_grad=True)
# tensor([1.9574], requires_grad=True) tensor([0.0969], requires_grad=True)
# tensor([1.9575], requires_grad=True) tensor([0.0967], requires_grad=True)
# tensor([1.9576], requires_grad=True) tensor([0.0965], requires_grad=True)
# tensor([1.9577], requires_grad=True) tensor([0.0962], requires_grad=True)
# tensor([1.9578], requires_grad=True) tensor([0.0960], requires_grad=True)
# tensor([1.9579], requires_grad=True) tensor([0.0958], requires_grad=True)
# tensor([1.9580], requires_grad=True) tensor([0.0955], requires_grad=True)
# tensor([1.9581], requires_grad=True) tensor([0.0953], requires_grad=True)
# tensor([1.9582], requires_grad=True) tensor([0.0951], requires_grad=True)
# tensor([1.9583], requires_grad=True) tensor([0.0948], requires_grad=True)
# tensor([1.9584], requires_grad=True) tensor([0.0946], requires_grad=True)
# tensor([1.9585], requires_grad=True) tensor([0.0944], requires_grad=True)
# tensor([1.9586], requires_grad=True) tensor([0.0942], requires_grad=True)
# tensor([1.9587], requires_grad=True) tensor([0.0939], requires_grad=True)
# tensor([1.9588], requires_grad=True) tensor([0.0937], requires_grad=True)
# tensor([1.9589], requires_grad=True) tensor([0.0935], requires_grad=True)
# tensor([1.9590], requires_grad=True) tensor([0.0933], requires_grad=True)
# tensor([1.9591], requires_grad=True) tensor([0.0930], requires_grad=True)
# tensor([1.9592], requires_grad=True) tensor([0.0928], requires_grad=True)
# tensor([1.9593], requires_grad=True) tensor([0.0926], requires_grad=True)
# tensor([1.9594], requires_grad=True) tensor([0.0924], requires_grad=True)
# tensor([1.9595], requires_grad=True) tensor([0.0921], requires_grad=True)
# tensor([1.9596], requires_grad=True) tensor([0.0919], requires_grad=True)
# tensor([1.9597], requires_grad=True) tensor([0.0917], requires_grad=True)
# tensor([1.9598], requires_grad=True) tensor([0.0915], requires_grad=True)
# tensor([1.9599], requires_grad=True) tensor([0.0913], requires_grad=True)
# tensor([1.9600], requires_grad=True) tensor([0.0910], requires_grad=True)
# tensor([1.9600], requires_grad=True) tensor([0.0908], requires_grad=True)
# tensor([1.9601], requires_grad=True) tensor([0.0906], requires_grad=True)
# tensor([1.9602], requires_grad=True) tensor([0.0904], requires_grad=True)
# tensor([1.9603], requires_grad=True) tensor([0.0902], requires_grad=True)
# tensor([1.9604], requires_grad=True) tensor([0.0899], requires_grad=True)
# tensor([1.9605], requires_grad=True) tensor([0.0897], requires_grad=True)
# tensor([1.9606], requires_grad=True) tensor([0.0895], requires_grad=True)
# tensor([1.9607], requires_grad=True) tensor([0.0893], requires_grad=True)
# tensor([1.9608], requires_grad=True) tensor([0.0891], requires_grad=True)
# tensor([1.9609], requires_grad=True) tensor([0.0889], requires_grad=True)
# tensor([1.9610], requires_grad=True) tensor([0.0887], requires_grad=True)
# tensor([1.9611], requires_grad=True) tensor([0.0884], requires_grad=True)
# tensor([1.9612], requires_grad=True) tensor([0.0882], requires_grad=True)
# tensor([1.9613], requires_grad=True) tensor([0.0880], requires_grad=True)
# tensor([1.9614], requires_grad=True) tensor([0.0878], requires_grad=True)
# tensor([1.9615], requires_grad=True) tensor([0.0876], requires_grad=True)
# tensor([1.9616], requires_grad=True) tensor([0.0874], requires_grad=True)
# tensor([1.9617], requires_grad=True) tensor([0.0872], requires_grad=True)
# tensor([1.9617], requires_grad=True) tensor([0.0870], requires_grad=True)
# tensor([1.9618], requires_grad=True) tensor([0.0868], requires_grad=True)
# tensor([1.9619], requires_grad=True) tensor([0.0865], requires_grad=True)
# tensor([1.9620], requires_grad=True) tensor([0.0863], requires_grad=True)
# tensor([1.9621], requires_grad=True) tensor([0.0861], requires_grad=True)
# tensor([1.9622], requires_grad=True) tensor([0.0859], requires_grad=True)
# tensor([1.9623], requires_grad=True) tensor([0.0857], requires_grad=True)
# tensor([1.9624], requires_grad=True) tensor([0.0855], requires_grad=True)
# tensor([1.9625], requires_grad=True) tensor([0.0853], requires_grad=True)
# tensor([1.9626], requires_grad=True) tensor([0.0851], requires_grad=True)
# tensor([1.9627], requires_grad=True) tensor([0.0849], requires_grad=True)
# tensor([1.9627], requires_grad=True) tensor([0.0847], requires_grad=True)
# tensor([1.9628], requires_grad=True) tensor([0.0845], requires_grad=True)
# tensor([1.9629], requires_grad=True) tensor([0.0843], requires_grad=True)
# tensor([1.9630], requires_grad=True) tensor([0.0841], requires_grad=True)
# tensor([1.9631], requires_grad=True) tensor([0.0839], requires_grad=True)
# tensor([1.9632], requires_grad=True) tensor([0.0837], requires_grad=True)
# tensor([1.9633], requires_grad=True) tensor([0.0835], requires_grad=True)
# tensor([1.9634], requires_grad=True) tensor([0.0833], requires_grad=True)
# tensor([1.9635], requires_grad=True) tensor([0.0831], requires_grad=True)
# tensor([1.9635], requires_grad=True) tensor([0.0829], requires_grad=True)
# tensor([1.9636], requires_grad=True) tensor([0.0827], requires_grad=True)
# tensor([1.9637], requires_grad=True) tensor([0.0825], requires_grad=True)
# tensor([1.9638], requires_grad=True) tensor([0.0823], requires_grad=True)
# tensor([1.9639], requires_grad=True) tensor([0.0821], requires_grad=True)
# tensor([1.9640], requires_grad=True) tensor([0.0819], requires_grad=True)
# tensor([1.9641], requires_grad=True) tensor([0.0817], requires_grad=True)
# tensor([1.9641], requires_grad=True) tensor([0.0815], requires_grad=True)
# tensor([1.9642], requires_grad=True) tensor([0.0813], requires_grad=True)
# tensor([1.9643], requires_grad=True) tensor([0.0811], requires_grad=True)
# tensor([1.9644], requires_grad=True) tensor([0.0809], requires_grad=True)
# tensor([1.9645], requires_grad=True) tensor([0.0807], requires_grad=True)
# tensor([1.9646], requires_grad=True) tensor([0.0805], requires_grad=True)
# tensor([1.9647], requires_grad=True) tensor([0.0803], requires_grad=True)
# tensor([1.9647], requires_grad=True) tensor([0.0801], requires_grad=True)
# tensor([1.9648], requires_grad=True) tensor([0.0799], requires_grad=True)
# tensor([1.9649], requires_grad=True) tensor([0.0797], requires_grad=True)
# tensor([1.9650], requires_grad=True) tensor([0.0796], requires_grad=True)
# tensor([1.9651], requires_grad=True) tensor([0.0794], requires_grad=True)
# tensor([1.9652], requires_grad=True) tensor([0.0792], requires_grad=True)
# tensor([1.9653], requires_grad=True) tensor([0.0790], requires_grad=True)
# tensor([1.9653], requires_grad=True) tensor([0.0788], requires_grad=True)
# tensor([1.9654], requires_grad=True) tensor([0.0786], requires_grad=True)
# tensor([1.9655], requires_grad=True) tensor([0.0784], requires_grad=True)
# tensor([1.9656], requires_grad=True) tensor([0.0782], requires_grad=True)
# tensor([1.9657], requires_grad=True) tensor([0.0780], requires_grad=True)
# tensor([1.9658], requires_grad=True) tensor([0.0779], requires_grad=True)
# tensor([1.9658], requires_grad=True) tensor([0.0777], requires_grad=True)
# tensor([1.9659], requires_grad=True) tensor([0.0775], requires_grad=True)
# tensor([1.9660], requires_grad=True) tensor([0.0773], requires_grad=True)
# tensor([1.9661], requires_grad=True) tensor([0.0771], requires_grad=True)
# tensor([1.9662], requires_grad=True) tensor([0.0769], requires_grad=True)
# tensor([1.9662], requires_grad=True) tensor([0.0767], requires_grad=True)
# tensor([1.9663], requires_grad=True) tensor([0.0766], requires_grad=True)
# tensor([1.9664], requires_grad=True) tensor([0.0764], requires_grad=True)
# tensor([1.9665], requires_grad=True) tensor([0.0762], requires_grad=True)
# tensor([1.9666], requires_grad=True) tensor([0.0760], requires_grad=True)
# tensor([1.9666], requires_grad=True) tensor([0.0758], requires_grad=True)
# tensor([1.9667], requires_grad=True) tensor([0.0756], requires_grad=True)
# tensor([1.9668], requires_grad=True) tensor([0.0755], requires_grad=True)
# tensor([1.9669], requires_grad=True) tensor([0.0753], requires_grad=True)
# tensor([1.9670], requires_grad=True) tensor([0.0751], requires_grad=True)
# tensor([1.9670], requires_grad=True) tensor([0.0749], requires_grad=True)
# tensor([1.9671], requires_grad=True) tensor([0.0747], requires_grad=True)
# tensor([1.9672], requires_grad=True) tensor([0.0746], requires_grad=True)
# tensor([1.9673], requires_grad=True) tensor([0.0744], requires_grad=True)
# tensor([1.9674], requires_grad=True) tensor([0.0742], requires_grad=True)
# tensor([1.9674], requires_grad=True) tensor([0.0740], requires_grad=True)
# tensor([1.9675], requires_grad=True) tensor([0.0738], requires_grad=True)
# tensor([1.9676], requires_grad=True) tensor([0.0737], requires_grad=True)
# tensor([1.9677], requires_grad=True) tensor([0.0735], requires_grad=True)
# tensor([1.9678], requires_grad=True) tensor([0.0733], requires_grad=True)
# tensor([1.9678], requires_grad=True) tensor([0.0731], requires_grad=True)
# tensor([1.9679], requires_grad=True) tensor([0.0730], requires_grad=True)
# tensor([1.9680], requires_grad=True) tensor([0.0728], requires_grad=True)
# tensor([1.9681], requires_grad=True) tensor([0.0726], requires_grad=True)
# tensor([1.9681], requires_grad=True) tensor([0.0724], requires_grad=True)
# tensor([1.9682], requires_grad=True) tensor([0.0723], requires_grad=True)
# tensor([1.9683], requires_grad=True) tensor([0.0721], requires_grad=True)
# tensor([1.9684], requires_grad=True) tensor([0.0719], requires_grad=True)
# tensor([1.9684], requires_grad=True) tensor([0.0717], requires_grad=True)
# tensor([1.9685], requires_grad=True) tensor([0.0716], requires_grad=True)
# tensor([1.9686], requires_grad=True) tensor([0.0714], requires_grad=True)
# tensor([1.9687], requires_grad=True) tensor([0.0712], requires_grad=True)
# tensor([1.9687], requires_grad=True) tensor([0.0710], requires_grad=True)
# tensor([1.9688], requires_grad=True) tensor([0.0709], requires_grad=True)
# tensor([1.9689], requires_grad=True) tensor([0.0707], requires_grad=True)
# tensor([1.9690], requires_grad=True) tensor([0.0705], requires_grad=True)
# tensor([1.9690], requires_grad=True) tensor([0.0704], requires_grad=True)
# tensor([1.9691], requires_grad=True) tensor([0.0702], requires_grad=True)
# tensor([1.9692], requires_grad=True) tensor([0.0700], requires_grad=True)
# tensor([1.9693], requires_grad=True) tensor([0.0699], requires_grad=True)
# tensor([1.9693], requires_grad=True) tensor([0.0697], requires_grad=True)
# tensor([1.9694], requires_grad=True) tensor([0.0695], requires_grad=True)
# tensor([1.9695], requires_grad=True) tensor([0.0694], requires_grad=True)
# tensor([1.9696], requires_grad=True) tensor([0.0692], requires_grad=True)
# tensor([1.9696], requires_grad=True) tensor([0.0690], requires_grad=True)
# tensor([1.9697], requires_grad=True) tensor([0.0689], requires_grad=True)
# tensor([1.9698], requires_grad=True) tensor([0.0687], requires_grad=True)
# tensor([1.9699], requires_grad=True) tensor([0.0685], requires_grad=True)
# tensor([1.9699], requires_grad=True) tensor([0.0684], requires_grad=True)
# tensor([1.9700], requires_grad=True) tensor([0.0682], requires_grad=True)
# tensor([1.9701], requires_grad=True) tensor([0.0680], requires_grad=True)
# tensor([1.9701], requires_grad=True) tensor([0.0679], requires_grad=True)
# tensor([1.9702], requires_grad=True) tensor([0.0677], requires_grad=True)
# tensor([1.9703], requires_grad=True) tensor([0.0675], requires_grad=True)
# tensor([1.9704], requires_grad=True) tensor([0.0674], requires_grad=True)
# tensor([1.9704], requires_grad=True) tensor([0.0672], requires_grad=True)
# tensor([1.9705], requires_grad=True) tensor([0.0671], requires_grad=True)
# tensor([1.9706], requires_grad=True) tensor([0.0669], requires_grad=True)
# tensor([1.9706], requires_grad=True) tensor([0.0667], requires_grad=True)
# tensor([1.9707], requires_grad=True) tensor([0.0666], requires_grad=True)
# tensor([1.9708], requires_grad=True) tensor([0.0664], requires_grad=True)

# %%
import torch.nn as nn
import torch.nn.functional as f
class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(1, 1)
    def forward(self, x):
        return self.linear(x)

# %%
model = LinearRegressionModel()

# %%
hypothesis = model(x_train)

# %%
print(hypothesis)
print(y_train)
# Out:
# tensor([[-0.5741],
#         [-1.1103],
#         [-1.6464]], grad_fn=<AddmmBackward>)
# tensor([[2.],
#         [4.],
#         [6.]])

# %%
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01)
for i in range(0, 1000):
    prediction = model(x_train)
    
    cost = f.mse_loss(prediction, y_train)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    print(prediction, cost.item())
# Out:
# tensor([[-0.5741],
#         [-1.1103],
#         [-1.6464]], grad_fn=<AddmmBackward>) 30.4029483795166
# tensor([[-0.2337],
#         [-0.5316],
#         [-0.8295]], grad_fn=<AddmmBackward>) 24.05585479736328
# tensor([[ 0.0689],
#         [-0.0172],
#         [-0.1032]], grad_fn=<AddmmBackward>) 19.0387020111084
# tensor([[0.3377],
#         [0.4402],
#         [0.5426]], grad_fn=<AddmmBackward>) 15.072795867919922
# tensor([[0.5766],
#         [0.8468],
#         [1.1169]], grad_fn=<AddmmBackward>) 11.937844276428223
# tensor([[0.7888],
#         [1.2082],
#         [1.6276]], grad_fn=<AddmmBackward>) 9.459720611572266
# tensor([[0.9774],
#         [1.5295],
#         [2.0816]], grad_fn=<AddmmBackward>) 7.500782012939453
# tensor([[1.1450],
#         [1.8152],
#         [2.4854]], grad_fn=<AddmmBackward>) 5.952234745025635
# tensor([[1.2938],
#         [2.0691],
#         [2.8445]], grad_fn=<AddmmBackward>) 4.728079319000244
# tensor([[1.4260],
#         [2.2949],
#         [3.1638]], grad_fn=<AddmmBackward>) 3.76033878326416
# tensor([[1.5434],
#         [2.4956],
#         [3.4478]], grad_fn=<AddmmBackward>) 2.9952805042266846
# tensor([[1.6476],
#         [2.6739],
#         [3.7003]], grad_fn=<AddmmBackward>) 2.3904330730438232
# tensor([[1.7401],
#         [2.8325],
#         [3.9249]], grad_fn=<AddmmBackward>) 1.9122234582901
# tensor([[1.8223],
#         [2.9735],
#         [4.1246]], grad_fn=<AddmmBackward>) 1.5341156721115112
# tensor([[1.8952],
#         [3.0988],
#         [4.3023]], grad_fn=<AddmmBackward>) 1.235133171081543
# tensor([[1.9599],
#         [3.2101],
#         [4.4603]], grad_fn=<AddmmBackward>) 0.9986955523490906
# tensor([[2.0173],
#         [3.3091],
#         [4.6009]], grad_fn=<AddmmBackward>) 0.8116962313652039
# tensor([[2.0682],
#         [3.3971],
#         [4.7260]], grad_fn=<AddmmBackward>) 0.6637763381004333
# tensor([[2.1133],
#         [3.4753],
#         [4.8372]], grad_fn=<AddmmBackward>) 0.5467470288276672
# tensor([[2.1533],
#         [3.5447],
#         [4.9362]], grad_fn=<AddmmBackward>) 0.4541357755661011
# tensor([[2.1887],
#         [3.6065],
#         [5.0243]], grad_fn=<AddmmBackward>) 0.38082602620124817
# tensor([[2.2201],
#         [3.6614],
#         [5.1027]], grad_fn=<AddmmBackward>) 0.32277390360832214
# tensor([[2.2479],
#         [3.7101],
#         [5.1724]], grad_fn=<AddmmBackward>) 0.2767823040485382
# tensor([[2.2724],
#         [3.7535],
#         [5.2345]], grad_fn=<AddmmBackward>) 0.24032437801361084
# tensor([[2.2941],
#         [3.7920],
#         [5.2898]], grad_fn=<AddmmBackward>) 0.21140296757221222
# tensor([[2.3133],
#         [3.8262],
#         [5.3390]], grad_fn=<AddmmBackward>) 0.1884389966726303
# tensor([[2.3302],
#         [3.8565],
#         [5.3828]], grad_fn=<AddmmBackward>) 0.17018501460552216
# tensor([[2.3452],
#         [3.8835],
#         [5.4219]], grad_fn=<AddmmBackward>) 0.15565408766269684
# tensor([[2.3583],
#         [3.9075],
#         [5.4566]], grad_fn=<AddmmBackward>) 0.1440666764974594
# tensor([[2.3699],
#         [3.9287],
#         [5.4876]], grad_fn=<AddmmBackward>) 0.13480646908283234
# tensor([[2.3800],
#         [3.9476],
#         [5.5152]], grad_fn=<AddmmBackward>) 0.12738637626171112
# tensor([[2.3889],
#         [3.9644],
#         [5.5399]], grad_fn=<AddmmBackward>) 0.1214209571480751
# tensor([[2.3967],
#         [3.9793],
#         [5.5618]], grad_fn=<AddmmBackward>) 0.11660625785589218
# tensor([[2.4035],
#         [3.9925],
#         [5.5814]], grad_fn=<AddmmBackward>) 0.11270131915807724
# tensor([[2.4095],
#         [4.0042],
#         [5.5989]], grad_fn=<AddmmBackward>) 0.10951623320579529
# tensor([[2.4146],
#         [4.0146],
#         [5.6145]], grad_fn=<AddmmBackward>) 0.10690031200647354
# tensor([[2.4191],
#         [4.0238],
#         [5.6285]], grad_fn=<AddmmBackward>) 0.10473501682281494
# tensor([[2.4229],
#         [4.0320],
#         [5.6410]], grad_fn=<AddmmBackward>) 0.10292616486549377
# tensor([[2.4262],
#         [4.0392],
#         [5.6522]], grad_fn=<AddmmBackward>) 0.10139983147382736
# tensor([[2.4290],
#         [4.0456],
#         [5.6621]], grad_fn=<AddmmBackward>) 0.10009702295064926
# tensor([[2.4314],
#         [4.0513],
#         [5.6711]], grad_fn=<AddmmBackward>) 0.0989714041352272
# tensor([[2.4334],
#         [4.0563],
#         [5.6791]], grad_fn=<AddmmBackward>) 0.09798648953437805
# tensor([[2.4351],
#         [4.0607],
#         [5.6863]], grad_fn=<AddmmBackward>) 0.09711295366287231
# tensor([[2.4364],
#         [4.0646],
#         [5.6928]], grad_fn=<AddmmBackward>) 0.09632807970046997
# tensor([[2.4375],
#         [4.0681],
#         [5.6986]], grad_fn=<AddmmBackward>) 0.09561378508806229
# tensor([[2.4383],
#         [4.0711],
#         [5.7039]], grad_fn=<AddmmBackward>) 0.09495554119348526
# tensor([[2.4390],
#         [4.0738],
#         [5.7086]], grad_fn=<AddmmBackward>) 0.09434229880571365
# tensor([[2.4394],
#         [4.0761],
#         [5.7129]], grad_fn=<AddmmBackward>) 0.09376499801874161
# tensor([[2.4397],
#         [4.0782],
#         [5.7168]], grad_fn=<AddmmBackward>) 0.09321638196706772
# tensor([[2.4398],
#         [4.0800],
#         [5.7203]], grad_fn=<AddmmBackward>) 0.09269105643033981
# tensor([[2.4398],
#         [4.0816],
#         [5.7235]], grad_fn=<AddmmBackward>) 0.09218461066484451
# tensor([[2.4397],
#         [4.0830],
#         [5.7264]], grad_fn=<AddmmBackward>) 0.09169331938028336
# tensor([[2.4394],
#         [4.0842],
#         [5.7290]], grad_fn=<AddmmBackward>) 0.09121471643447876
# tensor([[2.4391],
#         [4.0853],
#         [5.7314]], grad_fn=<AddmmBackward>) 0.09074635058641434
# tensor([[2.4387],
#         [4.0862],
#         [5.7336]], grad_fn=<AddmmBackward>) 0.09028660506010056
# tensor([[2.4383],
#         [4.0870],
#         [5.7357]], grad_fn=<AddmmBackward>) 0.08983403444290161
# tensor([[2.4377],
#         [4.0876],
#         [5.7375]], grad_fn=<AddmmBackward>) 0.08938774466514587
# tensor([[2.4371],
#         [4.0882],
#         [5.7393]], grad_fn=<AddmmBackward>) 0.08894658833742142
# tensor([[2.4365],
#         [4.0887],
#         [5.7409]], grad_fn=<AddmmBackward>) 0.08851009607315063
# tensor([[2.4358],
#         [4.0891],
#         [5.7424]], grad_fn=<AddmmBackward>) 0.08807777613401413
# tensor([[2.4351],
#         [4.0894],
#         [5.7438]], grad_fn=<AddmmBackward>) 0.08764886111021042
# tensor([[2.4343],
#         [4.0897],
#         [5.7451]], grad_fn=<AddmmBackward>) 0.08722341805696487
# tensor([[2.4335],
#         [4.0899],
#         [5.7463]], grad_fn=<AddmmBackward>) 0.08680088073015213
# tensor([[2.4327],
#         [4.0901],
#         [5.7475]], grad_fn=<AddmmBackward>) 0.08638118952512741
# tensor([[2.4319],
#         [4.0902],
#         [5.7486]], grad_fn=<AddmmBackward>) 0.08596409112215042
# tensor([[2.4310],
#         [4.0903],
#         [5.7496]], grad_fn=<AddmmBackward>) 0.08554941415786743
# tensor([[2.4302],
#         [4.0904],
#         [5.7506]], grad_fn=<AddmmBackward>) 0.085137277841568
# tensor([[2.4293],
#         [4.0904],
#         [5.7515]], grad_fn=<AddmmBackward>) 0.08472730964422226
# tensor([[2.4284],
#         [4.0904],
#         [5.7524]], grad_fn=<AddmmBackward>) 0.08431955426931381
# tensor([[2.4274],
#         [4.0904],
#         [5.7533]], grad_fn=<AddmmBackward>) 0.0839138850569725
# tensor([[2.4265],
#         [4.0903],
#         [5.7541]], grad_fn=<AddmmBackward>) 0.08351033180952072
# tensor([[2.4256],
#         [4.0902],
#         [5.7549]], grad_fn=<AddmmBackward>) 0.08310889452695847
# tensor([[2.4246],
#         [4.0902],
#         [5.7557]], grad_fn=<AddmmBackward>) 0.08270937204360962
# tensor([[2.4237],
#         [4.0901],
#         [5.7565]], grad_fn=<AddmmBackward>) 0.0823119729757309
# tensor([[2.4227],
#         [4.0900],
#         [5.7572]], grad_fn=<AddmmBackward>) 0.08191647380590439
# tensor([[2.4218],
#         [4.0898],
#         [5.7579]], grad_fn=<AddmmBackward>) 0.08152300119400024
# tensor([[2.4208],
#         [4.0897],
#         [5.7586]], grad_fn=<AddmmBackward>) 0.08113127946853638
# tensor([[2.4198],
#         [4.0896],
#         [5.7593]], grad_fn=<AddmmBackward>) 0.08074169605970383
# tensor([[2.4189],
#         [4.0894],
#         [5.7600]], grad_fn=<AddmmBackward>) 0.08035384118556976
# tensor([[2.4179],
#         [4.0893],
#         [5.7606]], grad_fn=<AddmmBackward>) 0.07996789366006851
# tensor([[2.4169],
#         [4.0891],
#         [5.7613]], grad_fn=<AddmmBackward>) 0.07958387583494186
# tensor([[2.4159],
#         [4.0889],
#         [5.7619]], grad_fn=<AddmmBackward>) 0.07920163124799728
# tensor([[2.4150],
#         [4.0888],
#         [5.7625]], grad_fn=<AddmmBackward>) 0.07882129400968552
# tensor([[2.4140],
#         [4.0886],
#         [5.7632]], grad_fn=<AddmmBackward>) 0.0784427598118782
# tensor([[2.4130],
#         [4.0884],
#         [5.7638]], grad_fn=<AddmmBackward>) 0.07806603610515594
# tensor([[2.4120],
#         [4.0882],
#         [5.7644]], grad_fn=<AddmmBackward>) 0.07769108563661575
# tensor([[2.4111],
#         [4.0880],
#         [5.7650]], grad_fn=<AddmmBackward>) 0.07731806486845016
# tensor([[2.4101],
#         [4.0878],
#         [5.7656]], grad_fn=<AddmmBackward>) 0.07694679498672485
# tensor([[2.4091],
#         [4.0877],
#         [5.7662]], grad_fn=<AddmmBackward>) 0.07657717913389206
# tensor([[2.4081],
#         [4.0875],
#         [5.7668]], grad_fn=<AddmmBackward>) 0.07620947808027267
# tensor([[2.4072],
#         [4.0873],
#         [5.7674]], grad_fn=<AddmmBackward>) 0.07584349066019058
# tensor([[2.4062],
#         [4.0871],
#         [5.7679]], grad_fn=<AddmmBackward>) 0.07547929137945175
# tensor([[2.4052],
#         [4.0869],
#         [5.7685]], grad_fn=<AddmmBackward>) 0.07511682063341141
# tensor([[2.4043],
#         [4.0867],
#         [5.7691]], grad_fn=<AddmmBackward>) 0.07475613802671432
# tensor([[2.4033],
#         [4.0865],
#         [5.7697]], grad_fn=<AddmmBackward>) 0.07439708709716797
# tensor([[2.4023],
#         [4.0863],
#         [5.7702]], grad_fn=<AddmmBackward>) 0.07403982430696487
# tensor([[2.4014],
#         [4.0861],
#         [5.7708]], grad_fn=<AddmmBackward>) 0.07368435710668564
# tensor([[2.4004],
#         [4.0859],
#         [5.7713]], grad_fn=<AddmmBackward>) 0.07333043962717056
# tensor([[2.3995],
#         [4.0857],
#         [5.7719]], grad_fn=<AddmmBackward>) 0.07297831028699875
# tensor([[2.3985],
#         [4.0855],
#         [5.7725]], grad_fn=<AddmmBackward>) 0.07262788712978363
# tensor([[2.3975],
#         [4.0853],
#         [5.7730]], grad_fn=<AddmmBackward>) 0.07227907329797745
# tensor([[2.3966],
#         [4.0851],
#         [5.7736]], grad_fn=<AddmmBackward>) 0.07193205505609512
# tensor([[2.3956],
#         [4.0849],
#         [5.7741]], grad_fn=<AddmmBackward>) 0.07158663868904114
# tensor([[2.3947],
#         [4.0847],
#         [5.7747]], grad_fn=<AddmmBackward>) 0.07124284654855728
# tensor([[2.3937],
#         [4.0845],
#         [5.7752]], grad_fn=<AddmmBackward>) 0.07090074568986893
# tensor([[2.3928],
#         [4.0843],
#         [5.7757]], grad_fn=<AddmmBackward>) 0.07056032121181488
# tensor([[2.3919],
#         [4.0841],
#         [5.7763]], grad_fn=<AddmmBackward>) 0.0702214241027832
# tensor([[2.3909],
#         [4.0839],
#         [5.7768]], grad_fn=<AddmmBackward>) 0.06988425552845001
# tensor([[2.3900],
#         [4.0837],
#         [5.7774]], grad_fn=<AddmmBackward>) 0.0695485845208168
# tensor([[2.3890],
#         [4.0835],
#         [5.7779]], grad_fn=<AddmmBackward>) 0.06921469420194626
# tensor([[2.3881],
#         [4.0833],
#         [5.7784]], grad_fn=<AddmmBackward>) 0.06888224929571152
# tensor([[2.3872],
#         [4.0831],
#         [5.7790]], grad_fn=<AddmmBackward>) 0.06855151802301407
# tensor([[2.3862],
#         [4.0829],
#         [5.7795]], grad_fn=<AddmmBackward>) 0.06822223216295242
# tensor([[2.3853],
#         [4.0827],
#         [5.7800]], grad_fn=<AddmmBackward>) 0.06789461523294449
# tensor([[2.3844],
#         [4.0825],
#         [5.7806]], grad_fn=<AddmmBackward>) 0.06756865978240967
# tensor([[2.3835],
#         [4.0823],
#         [5.7811]], grad_fn=<AddmmBackward>) 0.06724422425031662
# tensor([[2.3825],
#         [4.0821],
#         [5.7816]], grad_fn=<AddmmBackward>) 0.06692133098840714
# tensor([[2.3816],
#         [4.0819],
#         [5.7822]], grad_fn=<AddmmBackward>) 0.06659991294145584
# tensor([[2.3807],
#         [4.0817],
#         [5.7827]], grad_fn=<AddmmBackward>) 0.06628017872571945
# tensor([[2.3798],
#         [4.0815],
#         [5.7832]], grad_fn=<AddmmBackward>) 0.0659618154168129
# tensor([[2.3789],
#         [4.0813],
#         [5.7837]], grad_fn=<AddmmBackward>) 0.06564509868621826
# tensor([[2.3780],
#         [4.0811],
#         [5.7842]], grad_fn=<AddmmBackward>) 0.06532984226942062
# tensor([[2.3771],
#         [4.0809],
#         [5.7848]], grad_fn=<AddmmBackward>) 0.06501611322164536
# tensor([[2.3762],
#         [4.0807],
#         [5.7853]], grad_fn=<AddmmBackward>) 0.06470382213592529
# tensor([[2.3753],
#         [4.0805],
#         [5.7858]], grad_fn=<AddmmBackward>) 0.06439314037561417
# tensor([[2.3743],
#         [4.0803],
#         [5.7863]], grad_fn=<AddmmBackward>) 0.06408396363258362
# tensor([[2.3735],
#         [4.0801],
#         [5.7868]], grad_fn=<AddmmBackward>) 0.06377627700567245
# tensor([[2.3726],
#         [4.0799],
#         [5.7873]], grad_fn=<AddmmBackward>) 0.06346997618675232
# tensor([[2.3717],
#         [4.0798],
#         [5.7879]], grad_fn=<AddmmBackward>) 0.06316521763801575
# tensor([[2.3708],
#         [4.0796],
#         [5.7884]], grad_fn=<AddmmBackward>) 0.06286190450191498
# tensor([[2.3699],
#         [4.0794],
#         [5.7889]], grad_fn=<AddmmBackward>) 0.06255999207496643
# tensor([[2.3690],
#         [4.0792],
#         [5.7894]], grad_fn=<AddmmBackward>) 0.062259554862976074
# tensor([[2.3681],
#         [4.0790],
#         [5.7899]], grad_fn=<AddmmBackward>) 0.06196059659123421
# tensor([[2.3672],
#         [4.0788],
#         [5.7904]], grad_fn=<AddmmBackward>) 0.06166304275393486
# tensor([[2.3663],
#         [4.0786],
#         [5.7909]], grad_fn=<AddmmBackward>) 0.06136695668101311
# tensor([[2.3654],
#         [4.0784],
#         [5.7914]], grad_fn=<AddmmBackward>) 0.061072319746017456
# tensor([[2.3646],
#         [4.0782],
#         [5.7919]], grad_fn=<AddmmBackward>) 0.06077899411320686
# tensor([[2.3637],
#         [4.0780],
#         [5.7924]], grad_fn=<AddmmBackward>) 0.060487136244773865
# tensor([[2.3628],
#         [4.0779],
#         [5.7929]], grad_fn=<AddmmBackward>) 0.060196638107299805
# tensor([[2.3619],
#         [4.0777],
#         [5.7934]], grad_fn=<AddmmBackward>) 0.05990760028362274
# tensor([[2.3611],
#         [4.0775],
#         [5.7939]], grad_fn=<AddmmBackward>) 0.059619929641485214
# tensor([[2.3602],
#         [4.0773],
#         [5.7944]], grad_fn=<AddmmBackward>) 0.05933360755443573
# tensor([[2.3593],
#         [4.0771],
#         [5.7949]], grad_fn=<AddmmBackward>) 0.059048641473054886
# tensor([[2.3585],
#         [4.0769],
#         [5.7954]], grad_fn=<AddmmBackward>) 0.05876511335372925
# tensor([[2.3576],
#         [4.0767],
#         [5.7959]], grad_fn=<AddmmBackward>) 0.05848298594355583
# tensor([[2.3568],
#         [4.0766],
#         [5.7964]], grad_fn=<AddmmBackward>) 0.05820213258266449
# tensor([[2.3559],
#         [4.0764],
#         [5.7969]], grad_fn=<AddmmBackward>) 0.05792258307337761
# tensor([[2.3550],
#         [4.0762],
#         [5.7973]], grad_fn=<AddmmBackward>) 0.057644475251436234
# tensor([[2.3542],
#         [4.0760],
#         [5.7978]], grad_fn=<AddmmBackward>) 0.057367611676454544
# tensor([[2.3533],
#         [4.0758],
#         [5.7983]], grad_fn=<AddmmBackward>) 0.05709216371178627
# tensor([[2.3525],
#         [4.0756],
#         [5.7988]], grad_fn=<AddmmBackward>) 0.056817974895238876
# tensor([[2.3516],
#         [4.0755],
#         [5.7993]], grad_fn=<AddmmBackward>) 0.05654510483145714
# tensor([[2.3508],
#         [4.0753],
#         [5.7998]], grad_fn=<AddmmBackward>) 0.05627363920211792
# tensor([[2.3500],
#         [4.0751],
#         [5.8002]], grad_fn=<AddmmBackward>) 0.05600345507264137
# tensor([[2.3491],
#         [4.0749],
#         [5.8007]], grad_fn=<AddmmBackward>) 0.0557345449924469
# tensor([[2.3483],
#         [4.0747],
#         [5.8012]], grad_fn=<AddmmBackward>) 0.05546681955456734
# tensor([[2.3474],
#         [4.0746],
#         [5.8017]], grad_fn=<AddmmBackward>) 0.05520052835345268
# tensor([[2.3466],
#         [4.0744],
#         [5.8022]], grad_fn=<AddmmBackward>) 0.054935380816459656
# tensor([[2.3458],
#         [4.0742],
#         [5.8026]], grad_fn=<AddmmBackward>) 0.054671648889780045
# tensor([[2.3449],
#         [4.0740],
#         [5.8031]], grad_fn=<AddmmBackward>) 0.054409053176641464
# tensor([[2.3441],
#         [4.0738],
#         [5.8036]], grad_fn=<AddmmBackward>) 0.054147809743881226
# tensor([[2.3433],
#         [4.0737],
#         [5.8041]], grad_fn=<AddmmBackward>) 0.053887784481048584
# tensor([[2.3425],
#         [4.0735],
#         [5.8045]], grad_fn=<AddmmBackward>) 0.053628940135240555
# tensor([[2.3416],
#         [4.0733],
#         [5.8050]], grad_fn=<AddmmBackward>) 0.05337144061923027
# tensor([[2.3408],
#         [4.0731],
#         [5.8055]], grad_fn=<AddmmBackward>) 0.05311514064669609
# tensor([[2.3400],
#         [4.0730],
#         [5.8059]], grad_fn=<AddmmBackward>) 0.052860137075185776
# tensor([[2.3392],
#         [4.0728],
#         [5.8064]], grad_fn=<AddmmBackward>) 0.052606258541345596
# tensor([[2.3384],
#         [4.0726],
#         [5.8069]], grad_fn=<AddmmBackward>) 0.0523536317050457
# tensor([[2.3375],
#         [4.0724],
#         [5.8073]], grad_fn=<AddmmBackward>) 0.052102237939834595
# tensor([[2.3367],
#         [4.0723],
#         [5.8078]], grad_fn=<AddmmBackward>) 0.0518520325422287
# tensor([[2.3359],
#         [4.0721],
#         [5.8083]], grad_fn=<AddmmBackward>) 0.051603060215711594
# tensor([[2.3351],
#         [4.0719],
#         [5.8087]], grad_fn=<AddmmBackward>) 0.05135522410273552
# tensor([[2.3343],
#         [4.0717],
#         [5.8092]], grad_fn=<AddmmBackward>) 0.05110864341259003
# tensor([[2.3335],
#         [4.0716],
#         [5.8096]], grad_fn=<AddmmBackward>) 0.05086319521069527
# tensor([[2.3327],
#         [4.0714],
#         [5.8101]], grad_fn=<AddmmBackward>) 0.05061902478337288
# tensor([[2.3319],
#         [4.0712],
#         [5.8105]], grad_fn=<AddmmBackward>) 0.05037585273385048
# tensor([[2.3311],
#         [4.0711],
#         [5.8110]], grad_fn=<AddmmBackward>) 0.05013398453593254
# tensor([[2.3303],
#         [4.0709],
#         [5.8115]], grad_fn=<AddmmBackward>) 0.04989318177103996
# tensor([[2.3295],
#         [4.0707],
#         [5.8119]], grad_fn=<AddmmBackward>) 0.04965365305542946
# tensor([[2.3287],
#         [4.0705],
#         [5.8124]], grad_fn=<AddmmBackward>) 0.049415189772844315
# tensor([[2.3279],
#         [4.0704],
#         [5.8128]], grad_fn=<AddmmBackward>) 0.049177855253219604
# tensor([[2.3271],
#         [4.0702],
#         [5.8133]], grad_fn=<AddmmBackward>) 0.04894178733229637
# tensor([[2.3264],
#         [4.0700],
#         [5.8137]], grad_fn=<AddmmBackward>) 0.048706699162721634
# tensor([[2.3256],
#         [4.0699],
#         [5.8142]], grad_fn=<AddmmBackward>) 0.04847278073430061
# tensor([[2.3248],
#         [4.0697],
#         [5.8146]], grad_fn=<AddmmBackward>) 0.048240046948194504
# tensor([[2.3240],
#         [4.0695],
#         [5.8151]], grad_fn=<AddmmBackward>) 0.04800843074917793
# tensor([[2.3232],
#         [4.0694],
#         [5.8155]], grad_fn=<AddmmBackward>) 0.04777781292796135
# tensor([[2.3225],
#         [4.0692],
#         [5.8159]], grad_fn=<AddmmBackward>) 0.04754844307899475
# tensor([[2.3217],
#         [4.0690],
#         [5.8164]], grad_fn=<AddmmBackward>) 0.04732011631131172
# tensor([[2.3209],
#         [4.0689],
#         [5.8168]], grad_fn=<AddmmBackward>) 0.047092899680137634
# tensor([[2.3201],
#         [4.0687],
#         [5.8173]], grad_fn=<AddmmBackward>) 0.0468667596578598
# tensor([[2.3194],
#         [4.0685],
#         [5.8177]], grad_fn=<AddmmBackward>) 0.046641696244478226
# tensor([[2.3186],
#         [4.0684],
#         [5.8181]], grad_fn=<AddmmBackward>) 0.046417687088251114
# tensor([[2.3178],
#         [4.0682],
#         [5.8186]], grad_fn=<AddmmBackward>) 0.046194788068532944
# tensor([[2.3171],
#         [4.0680],
#         [5.8190]], grad_fn=<AddmmBackward>) 0.045973021537065506
# tensor([[2.3163],
#         [4.0679],
#         [5.8195]], grad_fn=<AddmmBackward>) 0.04575222730636597
# tensor([[2.3155],
#         [4.0677],
#         [5.8199]], grad_fn=<AddmmBackward>) 0.045532550662755966
# tensor([[2.3148],
#         [4.0676],
#         [5.8203]], grad_fn=<AddmmBackward>) 0.04531383141875267
# tensor([[2.3140],
#         [4.0674],
#         [5.8207]], grad_fn=<AddmmBackward>) 0.04509622976183891
# tensor([[2.3133],
#         [4.0672],
#         [5.8212]], grad_fn=<AddmmBackward>) 0.04487966373562813
# tensor([[2.3125],
#         [4.0671],
#         [5.8216]], grad_fn=<AddmmBackward>) 0.04466421529650688
# tensor([[2.3118],
#         [4.0669],
#         [5.8220]], grad_fn=<AddmmBackward>) 0.04444965720176697
# tensor([[2.3110],
#         [4.0667],
#         [5.8225]], grad_fn=<AddmmBackward>) 0.04423624649643898
# tensor([[2.3103],
#         [4.0666],
#         [5.8229]], grad_fn=<AddmmBackward>) 0.04402383044362068
# tensor([[2.3095],
#         [4.0664],
#         [5.8233]], grad_fn=<AddmmBackward>) 0.043812382966279984
# tensor([[2.3088],
#         [4.0663],
#         [5.8237]], grad_fn=<AddmmBackward>) 0.043601974844932556
# tensor([[2.3080],
#         [4.0661],
#         [5.8242]], grad_fn=<AddmmBackward>) 0.04339268431067467
# tensor([[2.3073],
#         [4.0659],
#         [5.8246]], grad_fn=<AddmmBackward>) 0.04318422079086304
# tensor([[2.3066],
#         [4.0658],
#         [5.8250]], grad_fn=<AddmmBackward>) 0.042976852506399155
# tensor([[2.3058],
#         [4.0656],
#         [5.8254]], grad_fn=<AddmmBackward>) 0.04277053102850914
# tensor([[2.3051],
#         [4.0655],
#         [5.8259]], grad_fn=<AddmmBackward>) 0.04256512597203255
# tensor([[2.3044],
#         [4.0653],
#         [5.8263]], grad_fn=<AddmmBackward>) 0.042360734194517136
# tensor([[2.3036],
#         [4.0652],
#         [5.8267]], grad_fn=<AddmmBackward>) 0.04215729236602783
# tensor([[2.3029],
#         [4.0650],
#         [5.8271]], grad_fn=<AddmmBackward>) 0.041954800486564636
# tensor([[2.3022],
#         [4.0648],
#         [5.8275]], grad_fn=<AddmmBackward>) 0.041753362864255905
# tensor([[2.3014],
#         [4.0647],
#         [5.8279]], grad_fn=<AddmmBackward>) 0.04155288264155388
# tensor([[2.3007],
#         [4.0645],
#         [5.8283]], grad_fn=<AddmmBackward>) 0.04135339707136154
# tensor([[2.3000],
#         [4.0644],
#         [5.8288]], grad_fn=<AddmmBackward>) 0.04115471616387367
# tensor([[2.2993],
#         [4.0642],
#         [5.8292]], grad_fn=<AddmmBackward>) 0.04095710441470146
# tensor([[2.2986],
#         [4.0641],
#         [5.8296]], grad_fn=<AddmmBackward>) 0.04076045751571655
# tensor([[2.2978],
#         [4.0639],
#         [5.8300]], grad_fn=<AddmmBackward>) 0.04056467488408089
# tensor([[2.2971],
#         [4.0638],
#         [5.8304]], grad_fn=<AddmmBackward>) 0.04036988690495491
# tensor([[2.2964],
#         [4.0636],
#         [5.8308]], grad_fn=<AddmmBackward>) 0.04017608240246773
# tensor([[2.2957],
#         [4.0635],
#         [5.8312]], grad_fn=<AddmmBackward>) 0.03998306766152382
# tensor([[2.2950],
#         [4.0633],
#         [5.8316]], grad_fn=<AddmmBackward>) 0.039791084825992584
# tensor([[2.2943],
#         [4.0632],
#         [5.8320]], grad_fn=<AddmmBackward>) 0.03960001468658447
# tensor([[2.2936],
#         [4.0630],
#         [5.8324]], grad_fn=<AddmmBackward>) 0.03940984979271889
# tensor([[2.2929],
#         [4.0628],
#         [5.8328]], grad_fn=<AddmmBackward>) 0.03922063484787941
# tensor([[2.2922],
#         [4.0627],
#         [5.8332]], grad_fn=<AddmmBackward>) 0.03903226926922798
# tensor([[2.2915],
#         [4.0625],
#         [5.8336]], grad_fn=<AddmmBackward>) 0.038844864815473557
# tensor([[2.2908],
#         [4.0624],
#         [5.8340]], grad_fn=<AddmmBackward>) 0.038658350706100464
# tensor([[2.2901],
#         [4.0622],
#         [5.8344]], grad_fn=<AddmmBackward>) 0.03847266733646393
# tensor([[2.2894],
#         [4.0621],
#         [5.8348]], grad_fn=<AddmmBackward>) 0.03828797861933708
# tensor([[2.2887],
#         [4.0619],
#         [5.8352]], grad_fn=<AddmmBackward>) 0.038104098290205
# tensor([[2.2880],
#         [4.0618],
#         [5.8356]], grad_fn=<AddmmBackward>) 0.03792116418480873
# tensor([[2.2873],
#         [4.0616],
#         [5.8360]], grad_fn=<AddmmBackward>) 0.03773903474211693
# tensor([[2.2866],
#         [4.0615],
#         [5.8364]], grad_fn=<AddmmBackward>) 0.03755781427025795
# tensor([[2.2859],
#         [4.0614],
#         [5.8368]], grad_fn=<AddmmBackward>) 0.03737742453813553
# tensor([[2.2852],
#         [4.0612],
#         [5.8372]], grad_fn=<AddmmBackward>) 0.037197913974523544
# tensor([[2.2845],
#         [4.0611],
#         [5.8376]], grad_fn=<AddmmBackward>) 0.03701934590935707
# tensor([[2.2838],
#         [4.0609],
#         [5.8380]], grad_fn=<AddmmBackward>) 0.036841560155153275
# tensor([[2.2832],
#         [4.0608],
#         [5.8384]], grad_fn=<AddmmBackward>) 0.03666462004184723
# tensor([[2.2825],
#         [4.0606],
#         [5.8388]], grad_fn=<AddmmBackward>) 0.036488551646471024
# tensor([[2.2818],
#         [4.0605],
#         [5.8391]], grad_fn=<AddmmBackward>) 0.03631332516670227
# tensor([[2.2811],
#         [4.0603],
#         [5.8395]], grad_fn=<AddmmBackward>) 0.036138925701379776
# tensor([[2.2804],
#         [4.0602],
#         [5.8399]], grad_fn=<AddmmBackward>) 0.035965390503406525
# tensor([[2.2798],
#         [4.0600],
#         [5.8403]], grad_fn=<AddmmBackward>) 0.03579272702336311
# tensor([[2.2791],
#         [4.0599],
#         [5.8407]], grad_fn=<AddmmBackward>) 0.035620786249637604
# tensor([[2.2784],
#         [4.0598],
#         [5.8411]], grad_fn=<AddmmBackward>) 0.0354497954249382
# tensor([[2.2778],
#         [4.0596],
#         [5.8415]], grad_fn=<AddmmBackward>) 0.035279542207717896
# tensor([[2.2771],
#         [4.0595],
#         [5.8418]], grad_fn=<AddmmBackward>) 0.03511011227965355
# tensor([[2.2764],
#         [4.0593],
#         [5.8422]], grad_fn=<AddmmBackward>) 0.034941527992486954
# tensor([[2.2758],
#         [4.0592],
#         [5.8426]], grad_fn=<AddmmBackward>) 0.03477372229099274
# tensor([[2.2751],
#         [4.0590],
#         [5.8430]], grad_fn=<AddmmBackward>) 0.03460672125220299
# tensor([[2.2744],
#         [4.0589],
#         [5.8434]], grad_fn=<AddmmBackward>) 0.03444052115082741
# tensor([[2.2738],
#         [4.0588],
#         [5.8437]], grad_fn=<AddmmBackward>) 0.034275200217962265
# tensor([[2.2731],
#         [4.0586],
#         [5.8441]], grad_fn=<AddmmBackward>) 0.03411057963967323
# tensor([[2.2725],
#         [4.0585],
#         [5.8445]], grad_fn=<AddmmBackward>) 0.03394676744937897
# tensor([[2.2718],
#         [4.0583],
#         [5.8449]], grad_fn=<AddmmBackward>) 0.03378376364707947
# tensor([[2.2712],
#         [4.0582],
#         [5.8452]], grad_fn=<AddmmBackward>) 0.033621564507484436
# tensor([[2.2705],
#         [4.0580],
#         [5.8456]], grad_fn=<AddmmBackward>) 0.03346008062362671
# tensor([[2.2699],
#         [4.0579],
#         [5.8460]], grad_fn=<AddmmBackward>) 0.03329938277602196
# tensor([[2.2692],
#         [4.0578],
#         [5.8463]], grad_fn=<AddmmBackward>) 0.03313950076699257
# tensor([[2.2686],
#         [4.0576],
#         [5.8467]], grad_fn=<AddmmBackward>) 0.032980360090732574
# tensor([[2.2679],
#         [4.0575],
#         [5.8471]], grad_fn=<AddmmBackward>) 0.032822009176015854
# tensor([[2.2673],
#         [4.0574],
#         [5.8474]], grad_fn=<AddmmBackward>) 0.032664358615875244
# tensor([[2.2666],
#         [4.0572],
#         [5.8478]], grad_fn=<AddmmBackward>) 0.03250749781727791
# tensor([[2.2660],
#         [4.0571],
#         [5.8482]], grad_fn=<AddmmBackward>) 0.032351430505514145
# tensor([[2.2653],
#         [4.0569],
#         [5.8485]], grad_fn=<AddmmBackward>) 0.03219607472419739
# tensor([[2.2647],
#         [4.0568],
#         [5.8489]], grad_fn=<AddmmBackward>) 0.032041482627391815
# tensor([[2.2641],
#         [4.0567],
#         [5.8493]], grad_fn=<AddmmBackward>) 0.03188754990696907
# tensor([[2.2634],
#         [4.0565],
#         [5.8496]], grad_fn=<AddmmBackward>) 0.03173443302512169
# tensor([[2.2628],
#         [4.0564],
#         [5.8500]], grad_fn=<AddmmBackward>) 0.031582050025463104
# tensor([[2.2622],
#         [4.0563],
#         [5.8504]], grad_fn=<AddmmBackward>) 0.0314304456114769
# tensor([[2.2615],
#         [4.0561],
#         [5.8507]], grad_fn=<AddmmBackward>) 0.03127950429916382
# tensor([[2.2609],
#         [4.0560],
#         [5.8511]], grad_fn=<AddmmBackward>) 0.031129278242588043
# tensor([[2.2603],
#         [4.0559],
#         [5.8514]], grad_fn=<AddmmBackward>) 0.030979758128523827
# tensor([[2.2597],
#         [4.0557],
#         [5.8518]], grad_fn=<AddmmBackward>) 0.030831066891551018
# tensor([[2.2590],
#         [4.0556],
#         [5.8521]], grad_fn=<AddmmBackward>) 0.03068297542631626
# tensor([[2.2584],
#         [4.0555],
#         [5.8525]], grad_fn=<AddmmBackward>) 0.03053564764559269
# tensor([[2.2578],
#         [4.0553],
#         [5.8529]], grad_fn=<AddmmBackward>) 0.030389009043574333
# tensor([[2.2572],
#         [4.0552],
#         [5.8532]], grad_fn=<AddmmBackward>) 0.03024309314787388
# tensor([[2.2566],
#         [4.0551],
#         [5.8536]], grad_fn=<AddmmBackward>) 0.030097849667072296
# tensor([[2.2559],
#         [4.0549],
#         [5.8539]], grad_fn=<AddmmBackward>) 0.029953328892588615
# tensor([[2.2553],
#         [4.0548],
#         [5.8543]], grad_fn=<AddmmBackward>) 0.029809439554810524
# tensor([[2.2547],
#         [4.0547],
#         [5.8546]], grad_fn=<AddmmBackward>) 0.029666343703866005
# tensor([[2.2541],
#         [4.0545],
#         [5.8550]], grad_fn=<AddmmBackward>) 0.029523836448788643
# tensor([[2.2535],
#         [4.0544],
#         [5.8553]], grad_fn=<AddmmBackward>) 0.029382066801190376
# tensor([[2.2529],
#         [4.0543],
#         [5.8557]], grad_fn=<AddmmBackward>) 0.029241031035780907
# tensor([[2.2523],
#         [4.0541],
#         [5.8560]], grad_fn=<AddmmBackward>) 0.02910059131681919
# tensor([[2.2517],
#         [4.0540],
#         [5.8564]], grad_fn=<AddmmBackward>) 0.028960824012756348
# tensor([[2.2511],
#         [4.0539],
#         [5.8567]], grad_fn=<AddmmBackward>) 0.028821736574172974
# tensor([[2.2504],
#         [4.0537],
#         [5.8570]], grad_fn=<AddmmBackward>) 0.028683358803391457
# tensor([[2.2498],
#         [4.0536],
#         [5.8574]], grad_fn=<AddmmBackward>) 0.02854561246931553
# tensor([[2.2492],
#         [4.0535],
#         [5.8577]], grad_fn=<AddmmBackward>) 0.028408505022525787
# tensor([[2.2486],
#         [4.0534],
#         [5.8581]], grad_fn=<AddmmBackward>) 0.028272094205021858
# tensor([[2.2480],
#         [4.0532],
#         [5.8584]], grad_fn=<AddmmBackward>) 0.02813631109893322
# tensor([[2.2475],
#         [4.0531],
#         [5.8588]], grad_fn=<AddmmBackward>) 0.028001241385936737
# tensor([[2.2469],
#         [4.0530],
#         [5.8591]], grad_fn=<AddmmBackward>) 0.027866734191775322
# tensor([[2.2463],
#         [4.0528],
#         [5.8594]], grad_fn=<AddmmBackward>) 0.027732932940125465
# tensor([[2.2457],
#         [4.0527],
#         [5.8598]], grad_fn=<AddmmBackward>) 0.027599751949310303
# tensor([[2.2451],
#         [4.0526],
#         [5.8601]], grad_fn=<AddmmBackward>) 0.027467258274555206
# tensor([[2.2445],
#         [4.0525],
#         [5.8604]], grad_fn=<AddmmBackward>) 0.027335330843925476
# tensor([[2.2439],
#         [4.0523],
#         [5.8608]], grad_fn=<AddmmBackward>) 0.02720404416322708
# tensor([[2.2433],
#         [4.0522],
#         [5.8611]], grad_fn=<AddmmBackward>) 0.027073418721556664
# tensor([[2.2427],
#         [4.0521],
#         [5.8614]], grad_fn=<AddmmBackward>) 0.026943432167172432
# tensor([[2.2422],
#         [4.0520],
#         [5.8618]], grad_fn=<AddmmBackward>) 0.026814036071300507
# tensor([[2.2416],
#         [4.0518],
#         [5.8621]], grad_fn=<AddmmBackward>) 0.02668524719774723
# tensor([[2.2410],
#         [4.0517],
#         [5.8624]], grad_fn=<AddmmBackward>) 0.02655714750289917
# tensor([[2.2404],
#         [4.0516],
#         [5.8628]], grad_fn=<AddmmBackward>) 0.026429584249854088
# tensor([[2.2398],
#         [4.0515],
#         [5.8631]], grad_fn=<AddmmBackward>) 0.026302697136998177
# tensor([[2.2393],
#         [4.0513],
#         [5.8634]], grad_fn=<AddmmBackward>) 0.026176372542977333
# tensor([[2.2387],
#         [4.0512],
#         [5.8638]], grad_fn=<AddmmBackward>) 0.02605070360004902
# tensor([[2.2381],
#         [4.0511],
#         [5.8641]], grad_fn=<AddmmBackward>) 0.025925571098923683
# tensor([[2.2375],
#         [4.0510],
#         [5.8644]], grad_fn=<AddmmBackward>) 0.0258010383695364
# tensor([[2.2370],
#         [4.0509],
#         [5.8647]], grad_fn=<AddmmBackward>) 0.025677161291241646
# tensor([[2.2364],
#         [4.0507],
#         [5.8651]], grad_fn=<AddmmBackward>) 0.025553852319717407
# tensor([[2.2358],
#         [4.0506],
#         [5.8654]], grad_fn=<AddmmBackward>) 0.025431184098124504
# tensor([[2.2353],
#         [4.0505],
#         [5.8657]], grad_fn=<AddmmBackward>) 0.025309063494205475
# tensor([[2.2347],
#         [4.0504],
#         [5.8660]], grad_fn=<AddmmBackward>) 0.025187497958540916
# tensor([[2.2341],
#         [4.0502],
#         [5.8664]], grad_fn=<AddmmBackward>) 0.02506653405725956
# tensor([[2.2336],
#         [4.0501],
#         [5.8667]], grad_fn=<AddmmBackward>) 0.024946220219135284
# tensor([[2.2330],
#         [4.0500],
#         [5.8670]], grad_fn=<AddmmBackward>) 0.024826427921652794
# tensor([[2.2324],
#         [4.0499],
#         [5.8673]], grad_fn=<AddmmBackward>) 0.024707162752747536
# tensor([[2.2319],
#         [4.0498],
#         [5.8676]], grad_fn=<AddmmBackward>) 0.024588530883193016
# tensor([[2.2313],
#         [4.0496],
#         [5.8680]], grad_fn=<AddmmBackward>) 0.024470480158925056
# tensor([[2.2308],
#         [4.0495],
#         [5.8683]], grad_fn=<AddmmBackward>) 0.02435297705233097
# tensor([[2.2302],
#         [4.0494],
#         [5.8686]], grad_fn=<AddmmBackward>) 0.024235984310507774
# tensor([[2.2297],
#         [4.0493],
#         [5.8689]], grad_fn=<AddmmBackward>) 0.024119630455970764
# tensor([[2.2291],
#         [4.0492],
#         [5.8692]], grad_fn=<AddmmBackward>) 0.024003779515624046
# tensor([[2.2286],
#         [4.0490],
#         [5.8695]], grad_fn=<AddmmBackward>) 0.023888522759079933
# tensor([[2.2280],
#         [4.0489],
#         [5.8699]], grad_fn=<AddmmBackward>) 0.02377382479608059
# tensor([[2.2275],
#         [4.0488],
#         [5.8702]], grad_fn=<AddmmBackward>) 0.023659618571400642
# tensor([[2.2269],
#         [4.0487],
#         [5.8705]], grad_fn=<AddmmBackward>) 0.023546045646071434
# tensor([[2.2264],
#         [4.0486],
#         [5.8708]], grad_fn=<AddmmBackward>) 0.023432979360222816
# tensor([[2.2258],
#         [4.0485],
#         [5.8711]], grad_fn=<AddmmBackward>) 0.02332044579088688
# tensor([[2.2253],
#         [4.0483],
#         [5.8714]], grad_fn=<AddmmBackward>) 0.02320845238864422
# tensor([[2.2247],
#         [4.0482],
#         [5.8717]], grad_fn=<AddmmBackward>) 0.023096993565559387
# tensor([[2.2242],
#         [4.0481],
#         [5.8720]], grad_fn=<AddmmBackward>) 0.022986112162470818
# tensor([[2.2237],
#         [4.0480],
#         [5.8723]], grad_fn=<AddmmBackward>) 0.022875716909766197
# tensor([[2.2231],
#         [4.0479],
#         [5.8726]], grad_fn=<AddmmBackward>) 0.022765854373574257
# tensor([[2.2226],
#         [4.0478],
#         [5.8729]], grad_fn=<AddmmBackward>) 0.022656487300992012
# tensor([[2.2221],
#         [4.0477],
#         [5.8733]], grad_fn=<AddmmBackward>) 0.022547759115695953
# tensor([[2.2215],
#         [4.0475],
#         [5.8736]], grad_fn=<AddmmBackward>) 0.022439485415816307
# tensor([[2.2210],
#         [4.0474],
#         [5.8739]], grad_fn=<AddmmBackward>) 0.022331679239869118
# tensor([[2.2205],
#         [4.0473],
#         [5.8742]], grad_fn=<AddmmBackward>) 0.02222444675862789
# tensor([[2.2199],
#         [4.0472],
#         [5.8745]], grad_fn=<AddmmBackward>) 0.02211773954331875
# tensor([[2.2194],
#         [4.0471],
#         [5.8748]], grad_fn=<AddmmBackward>) 0.02201150171458721
# tensor([[2.2189],
#         [4.0470],
#         [5.8751]], grad_fn=<AddmmBackward>) 0.0219058096408844
# tensor([[2.2183],
#         [4.0469],
#         [5.8754]], grad_fn=<AddmmBackward>) 0.021800599992275238
# tensor([[2.2178],
#         [4.0467],
#         [5.8757]], grad_fn=<AddmmBackward>) 0.021695943549275398
# tensor([[2.2173],
#         [4.0466],
#         [5.8760]], grad_fn=<AddmmBackward>) 0.02159176766872406
# tensor([[2.2168],
#         [4.0465],
#         [5.8763]], grad_fn=<AddmmBackward>) 0.021488092839717865
# tensor([[2.2163],
#         [4.0464],
#         [5.8766]], grad_fn=<AddmmBackward>) 0.02138487994670868
# tensor([[2.2157],
#         [4.0463],
#         [5.8769]], grad_fn=<AddmmBackward>) 0.021282173693180084
# tensor([[2.2152],
#         [4.0462],
#         [5.8772]], grad_fn=<AddmmBackward>) 0.021179979667067528
# tensor([[2.2147],
#         [4.0461],
#         [5.8775]], grad_fn=<AddmmBackward>) 0.021078243851661682
# tensor([[2.2142],
#         [4.0460],
#         [5.8777]], grad_fn=<AddmmBackward>) 0.020977072417736053
# tensor([[2.2137],
#         [4.0459],
#         [5.8780]], grad_fn=<AddmmBackward>) 0.020876331254839897
# tensor([[2.2132],
#         [4.0457],
#         [5.8783]], grad_fn=<AddmmBackward>) 0.020776087418198586
# tensor([[2.2126],
#         [4.0456],
#         [5.8786]], grad_fn=<AddmmBackward>) 0.020676275715231895
# tensor([[2.2121],
#         [4.0455],
#         [5.8789]], grad_fn=<AddmmBackward>) 0.02057698182761669
# tensor([[2.2116],
#         [4.0454],
#         [5.8792]], grad_fn=<AddmmBackward>) 0.020478205755352974
# tensor([[2.2111],
#         [4.0453],
#         [5.8795]], grad_fn=<AddmmBackward>) 0.02037983387708664
# tensor([[2.2106],
#         [4.0452],
#         [5.8798]], grad_fn=<AddmmBackward>) 0.02028203383088112
# tensor([[2.2101],
#         [4.0451],
#         [5.8801]], grad_fn=<AddmmBackward>) 0.020184582099318504
# tensor([[2.2096],
#         [4.0450],
#         [5.8804]], grad_fn=<AddmmBackward>) 0.02008769102394581
# tensor([[2.2091],
#         [4.0449],
#         [5.8807]], grad_fn=<AddmmBackward>) 0.01999123953282833
# tensor([[2.2086],
#         [4.0448],
#         [5.8809]], grad_fn=<AddmmBackward>) 0.01989523507654667
# tensor([[2.2081],
#         [4.0447],
#         [5.8812]], grad_fn=<AddmmBackward>) 0.01979967951774597
# tensor([[2.2076],
#         [4.0445],
#         [5.8815]], grad_fn=<AddmmBackward>) 0.01970459520816803
# tensor([[2.2071],
#         [4.0444],
#         [5.8818]], grad_fn=<AddmmBackward>) 0.019609956070780754
# tensor([[2.2066],
#         [4.0443],
#         [5.8821]], grad_fn=<AddmmBackward>) 0.019515782594680786
# tensor([[2.2061],
#         [4.0442],
#         [5.8824]], grad_fn=<AddmmBackward>) 0.019422076642513275
# tensor([[2.2056],
#         [4.0441],
#         [5.8826]], grad_fn=<AddmmBackward>) 0.019328808411955833
# tensor([[2.2051],
#         [4.0440],
#         [5.8829]], grad_fn=<AddmmBackward>) 0.01923598162829876
# tensor([[2.2046],
#         [4.0439],
#         [5.8832]], grad_fn=<AddmmBackward>) 0.019143635407090187
# tensor([[2.2041],
#         [4.0438],
#         [5.8835]], grad_fn=<AddmmBackward>) 0.01905166544020176
# tensor([[2.2036],
#         [4.0437],
#         [5.8838]], grad_fn=<AddmmBackward>) 0.018960168585181236
# tensor([[2.2031],
#         [4.0436],
#         [5.8841]], grad_fn=<AddmmBackward>) 0.018869146704673767
# tensor([[2.2026],
#         [4.0435],
#         [5.8843]], grad_fn=<AddmmBackward>) 0.01877855695784092
# tensor([[2.2022],
#         [4.0434],
#         [5.8846]], grad_fn=<AddmmBackward>) 0.018688365817070007
# tensor([[2.2017],
#         [4.0433],
#         [5.8849]], grad_fn=<AddmmBackward>) 0.01859861984848976
# tensor([[2.2012],
#         [4.0432],
#         [5.8852]], grad_fn=<AddmmBackward>) 0.018509333953261375
# tensor([[2.2007],
#         [4.0431],
#         [5.8854]], grad_fn=<AddmmBackward>) 0.018420429900288582
# tensor([[2.2002],
#         [4.0430],
#         [5.8857]], grad_fn=<AddmmBackward>) 0.0183319840580225
# tensor([[2.1997],
#         [4.0429],
#         [5.8860]], grad_fn=<AddmmBackward>) 0.018243910744786263
# tensor([[2.1993],
#         [4.0428],
#         [5.8863]], grad_fn=<AddmmBackward>) 0.018156329169869423
# tensor([[2.1988],
#         [4.0427],
#         [5.8865]], grad_fn=<AddmmBackward>) 0.018069131299853325
# tensor([[2.1983],
#         [4.0426],
#         [5.8868]], grad_fn=<AddmmBackward>) 0.017982393503189087
# tensor([[2.1978],
#         [4.0425],
#         [5.8871]], grad_fn=<AddmmBackward>) 0.0178960133343935
# tensor([[2.1974],
#         [4.0424],
#         [5.8874]], grad_fn=<AddmmBackward>) 0.01781011000275612
# tensor([[2.1969],
#         [4.0422],
#         [5.8876]], grad_fn=<AddmmBackward>) 0.017724547535181046
# tensor([[2.1964],
#         [4.0421],
#         [5.8879]], grad_fn=<AddmmBackward>) 0.01763940416276455
# tensor([[2.1959],
#         [4.0420],
#         [5.8882]], grad_fn=<AddmmBackward>) 0.017554720863699913
# tensor([[2.1955],
#         [4.0419],
#         [5.8884]], grad_fn=<AddmmBackward>) 0.017470434308052063
# tensor([[2.1950],
#         [4.0418],
#         [5.8887]], grad_fn=<AddmmBackward>) 0.017386551946401596
# tensor([[2.1945],
#         [4.0417],
#         [5.8890]], grad_fn=<AddmmBackward>) 0.01730303466320038
# tensor([[2.1941],
#         [4.0416],
#         [5.8892]], grad_fn=<AddmmBackward>) 0.017219936475157738
# tensor([[2.1936],
#         [4.0415],
#         [5.8895]], grad_fn=<AddmmBackward>) 0.01713724620640278
# tensor([[2.1931],
#         [4.0414],
#         [5.8898]], grad_fn=<AddmmBackward>) 0.017054958269000053
# tensor([[2.1927],
#         [4.0413],
#         [5.8900]], grad_fn=<AddmmBackward>) 0.016973089426755905
# tensor([[2.1922],
#         [4.0412],
#         [5.8903]], grad_fn=<AddmmBackward>) 0.016891570761799812
# tensor([[2.1917],
#         [4.0411],
#         [5.8906]], grad_fn=<AddmmBackward>) 0.01681048795580864
# tensor([[2.1913],
#         [4.0410],
#         [5.8908]], grad_fn=<AddmmBackward>) 0.016729729250073433
# tensor([[2.1908],
#         [4.0409],
#         [5.8911]], grad_fn=<AddmmBackward>) 0.016649393364787102
# tensor([[2.1904],
#         [4.0408],
#         [5.8913]], grad_fn=<AddmmBackward>) 0.01656944677233696
# tensor([[2.1899],
#         [4.0408],
#         [5.8916]], grad_fn=<AddmmBackward>) 0.01648988015949726
# tensor([[2.1894],
#         [4.0407],
#         [5.8919]], grad_fn=<AddmmBackward>) 0.01641065813601017
# tensor([[2.1890],
#         [4.0406],
#         [5.8921]], grad_fn=<AddmmBackward>) 0.016331857070326805
# tensor([[2.1885],
#         [4.0405],
#         [5.8924]], grad_fn=<AddmmBackward>) 0.016253480687737465
# tensor([[2.1881],
#         [4.0404],
#         [5.8926]], grad_fn=<AddmmBackward>) 0.0161754097789526
# tensor([[2.1876],
#         [4.0403],
#         [5.8929]], grad_fn=<AddmmBackward>) 0.01609775610268116
# tensor([[2.1872],
#         [4.0402],
#         [5.8932]], grad_fn=<AddmmBackward>) 0.01602044515311718
# tensor([[2.1867],
#         [4.0401],
#         [5.8934]], grad_fn=<AddmmBackward>) 0.015943504869937897
# tensor([[2.1863],
#         [4.0400],
#         [5.8937]], grad_fn=<AddmmBackward>) 0.015866940841078758
# tensor([[2.1858],
#         [4.0399],
#         [5.8939]], grad_fn=<AddmmBackward>) 0.015790749341249466
# tensor([[2.1854],
#         [4.0398],
#         [5.8942]], grad_fn=<AddmmBackward>) 0.01571493223309517
# tensor([[2.1849],
#         [4.0397],
#         [5.8944]], grad_fn=<AddmmBackward>) 0.015639418736100197
# tensor([[2.1845],
#         [4.0396],
#         [5.8947]], grad_fn=<AddmmBackward>) 0.015564375557005405
# tensor([[2.1840],
#         [4.0395],
#         [5.8949]], grad_fn=<AddmmBackward>) 0.015489608980715275
# tensor([[2.1836],
#         [4.0394],
#         [5.8952]], grad_fn=<AddmmBackward>) 0.01541524101048708
# tensor([[2.1832],
#         [4.0393],
#         [5.8955]], grad_fn=<AddmmBackward>) 0.015341196209192276
# tensor([[2.1827],
#         [4.0392],
#         [5.8957]], grad_fn=<AddmmBackward>) 0.015267523936927319
# tensor([[2.1823],
#         [4.0391],
#         [5.8960]], grad_fn=<AddmmBackward>) 0.015194208361208439
# tensor([[2.1818],
#         [4.0390],
#         [5.8962]], grad_fn=<AddmmBackward>) 0.015121228992938995
# tensor([[2.1814],
#         [4.0389],
#         [5.8965]], grad_fn=<AddmmBackward>) 0.015048607252538204
# tensor([[2.1810],
#         [4.0388],
#         [5.8967]], grad_fn=<AddmmBackward>) 0.014976349659264088
# tensor([[2.1805],
#         [4.0387],
#         [5.8969]], grad_fn=<AddmmBackward>) 0.014904444105923176
# tensor([[2.1801],
#         [4.0386],
#         [5.8972]], grad_fn=<AddmmBackward>) 0.014832902699708939
# tensor([[2.1797],
#         [4.0386],
#         [5.8974]], grad_fn=<AddmmBackward>) 0.014761646278202534
# tensor([[2.1792],
#         [4.0385],
#         [5.8977]], grad_fn=<AddmmBackward>) 0.014690748415887356
# tensor([[2.1788],
#         [4.0384],
#         [5.8979]], grad_fn=<AddmmBackward>) 0.014620199799537659
# tensor([[2.1784],
#         [4.0383],
#         [5.8982]], grad_fn=<AddmmBackward>) 0.014550012536346912
# tensor([[2.1779],
#         [4.0382],
#         [5.8984]], grad_fn=<AddmmBackward>) 0.014480105601251125
# tensor([[2.1775],
#         [4.0381],
#         [5.8987]], grad_fn=<AddmmBackward>) 0.01441060472279787
# tensor([[2.1771],
#         [4.0380],
#         [5.8989]], grad_fn=<AddmmBackward>) 0.014341396279633045
# tensor([[2.1767],
#         [4.0379],
#         [5.8992]], grad_fn=<AddmmBackward>) 0.014272538013756275
# tensor([[2.1762],
#         [4.0378],
#         [5.8994]], grad_fn=<AddmmBackward>) 0.014204022474586964
# tensor([[2.1758],
#         [4.0377],
#         [5.8996]], grad_fn=<AddmmBackward>) 0.014135756529867649
# tensor([[2.1754],
#         [4.0376],
#         [5.8999]], grad_fn=<AddmmBackward>) 0.014067928306758404
# tensor([[2.1750],
#         [4.0375],
#         [5.9001]], grad_fn=<AddmmBackward>) 0.014000347815454006
# tensor([[2.1746],
#         [4.0375],
#         [5.9004]], grad_fn=<AddmmBackward>) 0.013933130539953709
# tensor([[2.1741],
#         [4.0374],
#         [5.9006]], grad_fn=<AddmmBackward>) 0.013866211287677288
# tensor([[2.1737],
#         [4.0373],
#         [5.9008]], grad_fn=<AddmmBackward>) 0.013799612410366535
# tensor([[2.1733],
#         [4.0372],
#         [5.9011]], grad_fn=<AddmmBackward>) 0.013733357191085815
# tensor([[2.1729],
#         [4.0371],
#         [5.9013]], grad_fn=<AddmmBackward>) 0.013667416758835316
# tensor([[2.1725],
#         [4.0370],
#         [5.9016]], grad_fn=<AddmmBackward>) 0.013601772487163544
# tensor([[2.1721],
#         [4.0369],
#         [5.9018]], grad_fn=<AddmmBackward>) 0.013536459766328335
# tensor([[2.1716],
#         [4.0368],
#         [5.9020]], grad_fn=<AddmmBackward>) 0.013471454381942749
# tensor([[2.1712],
#         [4.0367],
#         [5.9023]], grad_fn=<AddmmBackward>) 0.013406775891780853
# tensor([[2.1708],
#         [4.0367],
#         [5.9025]], grad_fn=<AddmmBackward>) 0.013342401944100857
# tensor([[2.1704],
#         [4.0366],
#         [5.9027]], grad_fn=<AddmmBackward>) 0.013278321363031864
# tensor([[2.1700],
#         [4.0365],
#         [5.9030]], grad_fn=<AddmmBackward>) 0.013214565813541412
# tensor([[2.1696],
#         [4.0364],
#         [5.9032]], grad_fn=<AddmmBackward>) 0.013151085935533047
# tensor([[2.1692],
#         [4.0363],
#         [5.9034]], grad_fn=<AddmmBackward>) 0.013087931089103222
# tensor([[2.1688],
#         [4.0362],
#         [5.9037]], grad_fn=<AddmmBackward>) 0.013025102205574512
# tensor([[2.1684],
#         [4.0361],
#         [5.9039]], grad_fn=<AddmmBackward>) 0.012962531298398972
# tensor([[2.1680],
#         [4.0360],
#         [5.9041]], grad_fn=<AddmmBackward>) 0.012900316156446934
# tensor([[2.1676],
#         [4.0360],
#         [5.9044]], grad_fn=<AddmmBackward>) 0.012838342227041721
# tensor([[2.1672],
#         [4.0359],
#         [5.9046]], grad_fn=<AddmmBackward>) 0.01277672965079546
# tensor([[2.1668],
#         [4.0358],
#         [5.9048]], grad_fn=<AddmmBackward>) 0.012715364806354046
# tensor([[2.1664],
#         [4.0357],
#         [5.9050]], grad_fn=<AddmmBackward>) 0.012654274702072144
# tensor([[2.1660],
#         [4.0356],
#         [5.9053]], grad_fn=<AddmmBackward>) 0.012593486346304417
# tensor([[2.1656],
#         [4.0355],
#         [5.9055]], grad_fn=<AddmmBackward>) 0.012533060275018215
# tensor([[2.1652],
#         [4.0354],
#         [5.9057]], grad_fn=<AddmmBackward>) 0.012472838163375854
# tensor([[2.1648],
#         [4.0354],
#         [5.9060]], grad_fn=<AddmmBackward>) 0.012412951327860355
# tensor([[2.1644],
#         [4.0353],
#         [5.9062]], grad_fn=<AddmmBackward>) 0.012353355996310711
# tensor([[2.1640],
#         [4.0352],
#         [5.9064]], grad_fn=<AddmmBackward>) 0.012294036336243153
# tensor([[2.1636],
#         [4.0351],
#         [5.9066]], grad_fn=<AddmmBackward>) 0.01223496813327074
# tensor([[2.1632],
#         [4.0350],
#         [5.9069]], grad_fn=<AddmmBackward>) 0.012176222167909145
# tensor([[2.1628],
#         [4.0349],
#         [5.9071]], grad_fn=<AddmmBackward>) 0.012117770500481129
# tensor([[2.1624],
#         [4.0348],
#         [5.9073]], grad_fn=<AddmmBackward>) 0.012059577740728855
# tensor([[2.1620],
#         [4.0348],
#         [5.9075]], grad_fn=<AddmmBackward>) 0.012001652270555496
# tensor([[2.1616],
#         [4.0347],
#         [5.9078]], grad_fn=<AddmmBackward>) 0.011944040656089783
# tensor([[2.1612],
#         [4.0346],
#         [5.9080]], grad_fn=<AddmmBackward>) 0.01188667118549347
# tensor([[2.1608],
#         [4.0345],
#         [5.9082]], grad_fn=<AddmmBackward>) 0.011829580180346966
# tensor([[2.1605],
#         [4.0344],
#         [5.9084]], grad_fn=<AddmmBackward>) 0.011772791855037212
# tensor([[2.1601],
#         [4.0343],
# ...
# tensor([[2.0665],
#         [4.0143],
#         [5.9620]], grad_fn=<AddmmBackward>) 0.0020218126010149717
# tensor([[2.0663],
#         [4.0142],
#         [5.9621]], grad_fn=<AddmmBackward>) 0.002012101700529456
# tensor([[2.0662],
#         [4.0142],
#         [5.9622]], grad_fn=<AddmmBackward>) 0.0020024452824145555
# tensor([[2.0660],
#         [4.0142],
#         [5.9623]], grad_fn=<AddmmBackward>) 0.0019928275141865015
# tensor([[2.0659],
#         [4.0141],
#         [5.9624]], grad_fn=<AddmmBackward>) 0.0019832432735711336
# tensor([[2.0657],
#         [4.0141],
#         [5.9625]], grad_fn=<AddmmBackward>) 0.0019737223628908396
# tensor([[2.0655],
#         [4.0141],
#         [5.9626]], grad_fn=<AddmmBackward>) 0.0019642512779682875
# tensor([[2.0654],
#         [4.0140],
#         [5.9627]], grad_fn=<AddmmBackward>) 0.0019548102281987667
# tensor([[2.0652],
#         [4.0140],
#         [5.9628]], grad_fn=<AddmmBackward>) 0.0019454272696748376
# tensor([[2.0651],
#         [4.0140],
#         [5.9629]], grad_fn=<AddmmBackward>) 0.0019360760925337672
# tensor([[2.0649],
#         [4.0139],
#         [5.9629]], grad_fn=<AddmmBackward>) 0.0019267945317551494
# tensor([[2.0648],
#         [4.0139],
#         [5.9630]], grad_fn=<AddmmBackward>) 0.0019175350898876786
# tensor([[2.0646],
#         [4.0139],
#         [5.9631]], grad_fn=<AddmmBackward>) 0.0019083305960521102
# tensor([[2.0644],
#         [4.0138],
#         [5.9632]], grad_fn=<AddmmBackward>) 0.0018991567194461823
# tensor([[2.0643],
#         [4.0138],
#         [5.9633]], grad_fn=<AddmmBackward>) 0.0018900312716141343
# tensor([[2.0641],
#         [4.0138],
#         [5.9634]], grad_fn=<AddmmBackward>) 0.0018809670582413673
# tensor([[2.0640],
#         [4.0137],
#         [5.9635]], grad_fn=<AddmmBackward>) 0.0018719276413321495
# tensor([[2.0638],
#         [4.0137],
#         [5.9636]], grad_fn=<AddmmBackward>) 0.0018629375845193863
# tensor([[2.0637],
#         [4.0137],
#         [5.9637]], grad_fn=<AddmmBackward>) 0.0018540051532909274
# tensor([[2.0635],
#         [4.0136],
#         [5.9637]], grad_fn=<AddmmBackward>) 0.0018450943753123283
# tensor([[2.0634],
#         [4.0136],
#         [5.9638]], grad_fn=<AddmmBackward>) 0.0018362350529059768
# tensor([[2.0632],
#         [4.0136],
#         [5.9639]], grad_fn=<AddmmBackward>) 0.0018274228787049651
# tensor([[2.0631],
#         [4.0135],
#         [5.9640]], grad_fn=<AddmmBackward>) 0.0018186521483585238
# tensor([[2.0629],
#         [4.0135],
#         [5.9641]], grad_fn=<AddmmBackward>) 0.0018099193694069982
# tensor([[2.0628],
#         [4.0135],
#         [5.9642]], grad_fn=<AddmmBackward>) 0.0018012108048424125
# tensor([[2.0626],
#         [4.0134],
#         [5.9643]], grad_fn=<AddmmBackward>) 0.0017925756983458996
# tensor([[2.0625],
#         [4.0134],
#         [5.9643]], grad_fn=<AddmmBackward>) 0.0017839540960267186
# tensor([[2.0623],
#         [4.0134],
#         [5.9644]], grad_fn=<AddmmBackward>) 0.001775390119291842
# tensor([[2.0622],
#         [4.0133],
#         [5.9645]], grad_fn=<AddmmBackward>) 0.0017668624641373754
# tensor([[2.0620],
#         [4.0133],
#         [5.9646]], grad_fn=<AddmmBackward>) 0.0017583818407729268
# tensor([[2.0619],
#         [4.0133],
#         [5.9647]], grad_fn=<AddmmBackward>) 0.0017499345121905208
# tensor([[2.0617],
#         [4.0132],
#         [5.9648]], grad_fn=<AddmmBackward>) 0.0017415393376722932
# tensor([[2.0616],
#         [4.0132],
#         [5.9649]], grad_fn=<AddmmBackward>) 0.0017331758281216025
# tensor([[2.0614],
#         [4.0132],
#         [5.9649]], grad_fn=<AddmmBackward>) 0.0017248507356271148
# tensor([[2.0613],
#         [4.0131],
#         [5.9650]], grad_fn=<AddmmBackward>) 0.0017165690660476685
# tensor([[2.0611],
#         [4.0131],
#         [5.9651]], grad_fn=<AddmmBackward>) 0.0017083351267501712
# tensor([[2.0610],
#         [4.0131],
#         [5.9652]], grad_fn=<AddmmBackward>) 0.0017001237720251083
# tensor([[2.0608],
#         [4.0131],
#         [5.9653]], grad_fn=<AddmmBackward>) 0.0016919610789045691
# tensor([[2.0607],
#         [4.0130],
#         [5.9654]], grad_fn=<AddmmBackward>) 0.0016838290030136704
# tensor([[2.0605],
#         [4.0130],
#         [5.9654]], grad_fn=<AddmmBackward>) 0.0016757402336224914
# tensor([[2.0604],
#         [4.0130],
#         [5.9655]], grad_fn=<AddmmBackward>) 0.0016676968662068248
# tensor([[2.0602],
#         [4.0129],
#         [5.9656]], grad_fn=<AddmmBackward>) 0.0016596972709521651
# tensor([[2.0601],
#         [4.0129],
#         [5.9657]], grad_fn=<AddmmBackward>) 0.0016517252661287785
# tensor([[2.0600],
#         [4.0129],
#         [5.9658]], grad_fn=<AddmmBackward>) 0.0016437927260994911
# tensor([[2.0598],
#         [4.0128],
#         [5.9659]], grad_fn=<AddmmBackward>) 0.001635899767279625
# tensor([[2.0597],
#         [4.0128],
#         [5.9659]], grad_fn=<AddmmBackward>) 0.0016280446434393525
# tensor([[2.0595],
#         [4.0128],
#         [5.9660]], grad_fn=<AddmmBackward>) 0.0016202274709939957
# tensor([[2.0594],
#         [4.0127],
#         [5.9661]], grad_fn=<AddmmBackward>) 0.0016124439425766468
# tensor([[2.0592],
#         [4.0127],
#         [5.9662]], grad_fn=<AddmmBackward>) 0.0016046966193243861
# tensor([[2.0591],
#         [4.0127],
#         [5.9663]], grad_fn=<AddmmBackward>) 0.0015969881787896156
# tensor([[2.0590],
#         [4.0127],
#         [5.9663]], grad_fn=<AddmmBackward>) 0.001589318155311048
# tensor([[2.0588],
#         [4.0126],
#         [5.9664]], grad_fn=<AddmmBackward>) 0.0015816866653040051
# tensor([[2.0587],
#         [4.0126],
#         [5.9665]], grad_fn=<AddmmBackward>) 0.0015740962699055672
# tensor([[2.0585],
#         [4.0126],
#         [5.9666]], grad_fn=<AddmmBackward>) 0.0015665387036278844
# tensor([[2.0584],
#         [4.0125],
#         [5.9667]], grad_fn=<AddmmBackward>) 0.0015590139664709568
# tensor([[2.0582],
#         [4.0125],
#         [5.9668]], grad_fn=<AddmmBackward>) 0.0015515349805355072
# tensor([[2.0581],
#         [4.0125],
#         [5.9668]], grad_fn=<AddmmBackward>) 0.001544083352200687
# tensor([[2.0580],
#         [4.0124],
#         [5.9669]], grad_fn=<AddmmBackward>) 0.001536669209599495
# tensor([[2.0578],
#         [4.0124],
#         [5.9670]], grad_fn=<AddmmBackward>) 0.0015292823081836104
# tensor([[2.0577],
#         [4.0124],
#         [5.9671]], grad_fn=<AddmmBackward>) 0.0015219353372231126
# tensor([[2.0576],
#         [4.0124],
#         [5.9671]], grad_fn=<AddmmBackward>) 0.0015146309742704034
# tensor([[2.0574],
#         [4.0123],
#         [5.9672]], grad_fn=<AddmmBackward>) 0.0015073585091158748
# tensor([[2.0573],
#         [4.0123],
#         [5.9673]], grad_fn=<AddmmBackward>) 0.0015001281863078475
# tensor([[2.0571],
#         [4.0123],
#         [5.9674]], grad_fn=<AddmmBackward>) 0.00149290740955621
# tensor([[2.0570],
#         [4.0122],
#         [5.9675]], grad_fn=<AddmmBackward>) 0.0014857365749776363
# tensor([[2.0569],
#         [4.0122],
#         [5.9675]], grad_fn=<AddmmBackward>) 0.0014786074170842767
# tensor([[2.0567],
#         [4.0122],
#         [5.9676]], grad_fn=<AddmmBackward>) 0.0014715096913278103
# tensor([[2.0566],
#         [4.0121],
#         [5.9677]], grad_fn=<AddmmBackward>) 0.0014644429320469499
# tensor([[2.0565],
#         [4.0121],
#         [5.9678]], grad_fn=<AddmmBackward>) 0.0014574151718989015
# tensor([[2.0563],
#         [4.0121],
#         [5.9679]], grad_fn=<AddmmBackward>) 0.001450414420105517
# tensor([[2.0562],
#         [4.0121],
#         [5.9679]], grad_fn=<AddmmBackward>) 0.0014434383483603597
# tensor([[2.0560],
#         [4.0120],
#         [5.9680]], grad_fn=<AddmmBackward>) 0.001436517108231783
# tensor([[2.0559],
#         [4.0120],
#         [5.9681]], grad_fn=<AddmmBackward>) 0.0014296151930466294
# tensor([[2.0558],
#         [4.0120],
#         [5.9682]], grad_fn=<AddmmBackward>) 0.0014227539068087935
# tensor([[2.0556],
#         [4.0119],
#         [5.9682]], grad_fn=<AddmmBackward>) 0.0014159228885546327
# tensor([[2.0555],
#         [4.0119],
#         [5.9683]], grad_fn=<AddmmBackward>) 0.0014091323828324676
# tensor([[2.0554],
#         [4.0119],
#         [5.9684]], grad_fn=<AddmmBackward>) 0.0014023504918441176
# tensor([[2.0552],
#         [4.0119],
#         [5.9685]], grad_fn=<AddmmBackward>) 0.0013956227339804173
# tensor([[2.0551],
#         [4.0118],
#         [5.9685]], grad_fn=<AddmmBackward>) 0.0013889236142858863
# tensor([[2.0550],
#         [4.0118],
#         [5.9686]], grad_fn=<AddmmBackward>) 0.0013822555774822831
# tensor([[2.0548],
#         [4.0118],
#         [5.9687]], grad_fn=<AddmmBackward>) 0.0013756147818639874
# tensor([[2.0547],
#         [4.0117],
#         [5.9688]], grad_fn=<AddmmBackward>) 0.0013690049527212977
# tensor([[2.0546],
#         [4.0117],
#         [5.9688]], grad_fn=<AddmmBackward>) 0.001362423412501812
# tensor([[2.0545],
#         [4.0117],
#         [5.9689]], grad_fn=<AddmmBackward>) 0.0013558849459514022
# tensor([[2.0543],
#         [4.0117],
#         [5.9690]], grad_fn=<AddmmBackward>) 0.0013493719743564725
# tensor([[2.0542],
#         [4.0116],
#         [5.9691]], grad_fn=<AddmmBackward>) 0.0013429006794467568
# tensor([[2.0541],
#         [4.0116],
#         [5.9691]], grad_fn=<AddmmBackward>) 0.0013364447513595223
# tensor([[2.0539],
#         [4.0116],
#         [5.9692]], grad_fn=<AddmmBackward>) 0.001330035156570375
# tensor([[2.0538],
#         [4.0115],
#         [5.9693]], grad_fn=<AddmmBackward>) 0.0013236458180472255
# tensor([[2.0537],
#         [4.0115],
#         [5.9694]], grad_fn=<AddmmBackward>) 0.0013172924518585205
# tensor([[2.0535],
#         [4.0115],
#         [5.9694]], grad_fn=<AddmmBackward>) 0.0013109641149640083
# tensor([[2.0534],
#         [4.0115],
#         [5.9695]], grad_fn=<AddmmBackward>) 0.0013046669773757458
# tensor([[2.0533],
#         [4.0114],
#         [5.9696]], grad_fn=<AddmmBackward>) 0.0012984041823074222
# tensor([[2.0532],
#         [4.0114],
#         [5.9697]], grad_fn=<AddmmBackward>) 0.0012921768939122558
# tensor([[2.0530],
#         [4.0114],
#         [5.9697]], grad_fn=<AddmmBackward>) 0.001285959966480732
# tensor([[2.0529],
#         [4.0114],
#         [5.9698]], grad_fn=<AddmmBackward>) 0.0012797891395166516
# tensor([[2.0528],
#         [4.0113],
#         [5.9699]], grad_fn=<AddmmBackward>) 0.0012736499775201082
# tensor([[2.0526],
#         [4.0113],
#         [5.9699]], grad_fn=<AddmmBackward>) 0.0012675338657572865
# tensor([[2.0525],
#         [4.0113],
#         [5.9700]], grad_fn=<AddmmBackward>) 0.0012614409206435084
# tensor([[2.0524],
#         [4.0112],
#         [5.9701]], grad_fn=<AddmmBackward>) 0.0012553792912513018
# tensor([[2.0523],
#         [4.0112],
#         [5.9702]], grad_fn=<AddmmBackward>) 0.0012493630638346076
# tensor([[2.0521],
#         [4.0112],
#         [5.9702]], grad_fn=<AddmmBackward>) 0.001243356498889625
# tensor([[2.0520],
#         [4.0112],
#         [5.9703]], grad_fn=<AddmmBackward>) 0.0012373857898637652
# tensor([[2.0519],
#         [4.0111],
#         [5.9704]], grad_fn=<AddmmBackward>) 0.0012314340565353632
# tensor([[2.0518],
#         [4.0111],
#         [5.9705]], grad_fn=<AddmmBackward>) 0.001225526095367968
# tensor([[2.0516],
#         [4.0111],
#         [5.9705]], grad_fn=<AddmmBackward>) 0.0012196406023576856
# tensor([[2.0515],
#         [4.0111],
#         [5.9706]], grad_fn=<AddmmBackward>) 0.0012137891026213765
# tensor([[2.0514],
#         [4.0110],
#         [5.9707]], grad_fn=<AddmmBackward>) 0.0012079575099050999
# tensor([[2.0513],
#         [4.0110],
#         [5.9707]], grad_fn=<AddmmBackward>) 0.0012021561851724982
# tensor([[2.0511],
#         [4.0110],
#         [5.9708]], grad_fn=<AddmmBackward>) 0.0011963899014517665
# tensor([[2.0510],
#         [4.0110],
#         [5.9709]], grad_fn=<AddmmBackward>) 0.0011906326981261373
# tensor([[2.0509],
#         [4.0109],
#         [5.9709]], grad_fn=<AddmmBackward>) 0.0011849183356389403
# tensor([[2.0508],
#         [4.0109],
#         [5.9710]], grad_fn=<AddmmBackward>) 0.0011792361037805676
# tensor([[2.0507],
#         [4.0109],
#         [5.9711]], grad_fn=<AddmmBackward>) 0.0011735744774341583
# tensor([[2.0505],
#         [4.0108],
#         [5.9712]], grad_fn=<AddmmBackward>) 0.0011679345043376088
# tensor([[2.0504],
#         [4.0108],
#         [5.9712]], grad_fn=<AddmmBackward>) 0.0011623252648860216
# tensor([[2.0503],
#         [4.0108],
#         [5.9713]], grad_fn=<AddmmBackward>) 0.0011567397741600871
# tensor([[2.0502],
#         [4.0108],
#         [5.9714]], grad_fn=<AddmmBackward>) 0.00115118152461946
# tensor([[2.0501],
#         [4.0107],
#         [5.9714]], grad_fn=<AddmmBackward>) 0.0011456649517640471
# tensor([[2.0499],
#         [4.0107],
#         [5.9715]], grad_fn=<AddmmBackward>) 0.0011401526862755418
# tensor([[2.0498],
#         [4.0107],
#         [5.9716]], grad_fn=<AddmmBackward>) 0.0011346874525770545
# tensor([[2.0497],
#         [4.0107],
#         [5.9716]], grad_fn=<AddmmBackward>) 0.001129237818531692
# tensor([[2.0496],
#         [4.0106],
#         [5.9717]], grad_fn=<AddmmBackward>) 0.0011238068109378219
# tensor([[2.0495],
#         [4.0106],
#         [5.9718]], grad_fn=<AddmmBackward>) 0.0011184214381501079
# tensor([[2.0493],
#         [4.0106],
#         [5.9718]], grad_fn=<AddmmBackward>) 0.0011130489874631166
# tensor([[2.0492],
#         [4.0106],
#         [5.9719]], grad_fn=<AddmmBackward>) 0.0011077006347477436
# tensor([[2.0491],
#         [4.0105],
#         [5.9720]], grad_fn=<AddmmBackward>) 0.0011023808037862182
# tensor([[2.0490],
#         [4.0105],
#         [5.9720]], grad_fn=<AddmmBackward>) 0.0010970905423164368
# tensor([[2.0489],
#         [4.0105],
#         [5.9721]], grad_fn=<AddmmBackward>) 0.001091820653527975
# tensor([[2.0487],
#         [4.0105],
#         [5.9722]], grad_fn=<AddmmBackward>) 0.0010865700896829367
# tensor([[2.0486],
#         [4.0104],
#         [5.9722]], grad_fn=<AddmmBackward>) 0.001081349910236895
# tensor([[2.0485],
#         [4.0104],
#         [5.9723]], grad_fn=<AddmmBackward>) 0.0010761698940768838
# tensor([[2.0484],
#         [4.0104],
#         [5.9724]], grad_fn=<AddmmBackward>) 0.001070997677743435
# tensor([[2.0483],
#         [4.0104],
#         [5.9724]], grad_fn=<AddmmBackward>) 0.0010658468818292022
# tensor([[2.0482],
#         [4.0103],
#         [5.9725]], grad_fn=<AddmmBackward>) 0.001060743466950953
# tensor([[2.0480],
#         [4.0103],
#         [5.9726]], grad_fn=<AddmmBackward>) 0.0010556348133832216
# tensor([[2.0479],
#         [4.0103],
#         [5.9726]], grad_fn=<AddmmBackward>) 0.0010505710961297154
# tensor([[2.0478],
#         [4.0103],
#         [5.9727]], grad_fn=<AddmmBackward>) 0.0010455228621140122
# tensor([[2.0477],
#         [4.0102],
#         [5.9728]], grad_fn=<AddmmBackward>) 0.0010405074572190642
# tensor([[2.0476],
#         [4.0102],
#         [5.9728]], grad_fn=<AddmmBackward>) 0.0010355116100981832
# tensor([[2.0475],
#         [4.0102],
#         [5.9729]], grad_fn=<AddmmBackward>) 0.001030535320751369
# tensor([[2.0474],
#         [4.0102],
#         [5.9730]], grad_fn=<AddmmBackward>) 0.0010255892993882298
# tensor([[2.0472],
#         [4.0101],
#         [5.9730]], grad_fn=<AddmmBackward>) 0.0010206635342910886
# tensor([[2.0471],
#         [4.0101],
#         [5.9731]], grad_fn=<AddmmBackward>) 0.0010157650103792548
# tensor([[2.0470],
#         [4.0101],
#         [5.9732]], grad_fn=<AddmmBackward>) 0.0010108832502737641
# tensor([[2.0469],
#         [4.0101],
#         [5.9732]], grad_fn=<AddmmBackward>) 0.0010060336207970977
# tensor([[2.0468],
#         [4.0100],
#         [5.9733]], grad_fn=<AddmmBackward>) 0.001001200987957418
# tensor([[2.0467],
#         [4.0100],
#         [5.9734]], grad_fn=<AddmmBackward>) 0.0009963958291336894
# tensor([[2.0466],
#         [4.0100],
#         [5.9734]], grad_fn=<AddmmBackward>) 0.0009916129056364298
# tensor([[2.0465],
#         [4.0100],
#         [5.9735]], grad_fn=<AddmmBackward>) 0.0009868477936834097
# tensor([[2.0463],
#         [4.0099],
#         [5.9735]], grad_fn=<AddmmBackward>) 0.0009820993291214108
# tensor([[2.0462],
#         [4.0099],
#         [5.9736]], grad_fn=<AddmmBackward>) 0.000977388583123684
# tensor([[2.0461],
#         [4.0099],
#         [5.9737]], grad_fn=<AddmmBackward>) 0.0009726965799927711
# tensor([[2.0460],
#         [4.0099],
#         [5.9737]], grad_fn=<AddmmBackward>) 0.0009680230286903679
# tensor([[2.0459],
#         [4.0098],
#         [5.9738]], grad_fn=<AddmmBackward>) 0.0009633847512304783
# tensor([[2.0458],
#         [4.0098],
#         [5.9739]], grad_fn=<AddmmBackward>) 0.0009587514796294272
# tensor([[2.0457],
#         [4.0098],
#         [5.9739]], grad_fn=<AddmmBackward>) 0.0009541416657157242
